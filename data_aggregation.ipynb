# %%
import pandas as pd

fbref_data = pd.read_csv('./data/new_matches.csv')
fbref_data.columns = fbref_data.columns.str.lower()
fbref_data['date'] = pd.to_datetime(fbref_data['date'])
fbref_data
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5515 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5516 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5517 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5518 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5519 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
df_17 = pd.read_csv('./data/17_18.csv')
df_18 = pd.read_csv('./data/18_19.csv')
df_19 = pd.read_csv('./data/19_20.csv')
df_20 = pd.read_csv('./data/20_21.csv')
df_21 = pd.read_csv('./data/21_22.csv')
df_22 = pd.read_csv('./data/22_23.csv')
df_23 = pd.read_csv('./data/23_24.csv')
df_24 = pd.read_csv('./data/24_25.csv')
df_17 = df_17[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'BbAv>2.5', 'BbAv<2.5']]
df_18 = df_18[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'BbAv>2.5', 'BbAv<2.5']]
df_19 = df_19[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'B365>2.5', 'B365<2.5']]
df_20 = df_20[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'B365>2.5', 'B365<2.5']]
df_21 = df_21[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'B365>2.5', 'B365<2.5']]
df_22 = df_22[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'B365>2.5', 'B365<2.5']]
df_23 = df_23[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'B365>2.5', 'B365<2.5']]
df_24 = df_24[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'B365>2.5', 'B365<2.5']]
print(len(df_17), len(df_18), len(df_19), len(df_20), len(df_21), len(df_22), len(df_23), len(df_24))
# Out:
# 380 380 380 380 380 380 380 100

# %%
df_17.rename(columns={'BbAv>2.5' : 'over2.5', 'BbAv<2.5' : 'under2.5'}, inplace=True)
df_18.rename(columns={'BbAv>2.5' : 'over2.5', 'BbAv<2.5' : 'under2.5'}, inplace=True)
df_19.rename(columns={'B365>2.5' : 'over2.5', 'B365<2.5' : 'under2.5'}, inplace=True)
df_20.rename(columns={'B365>2.5' : 'over2.5', 'B365<2.5' : 'under2.5'}, inplace=True)
df_21.rename(columns={'B365>2.5' : 'over2.5', 'B365<2.5' : 'under2.5'}, inplace=True)
df_22.rename(columns={'B365>2.5' : 'over2.5', 'B365<2.5' : 'under2.5'}, inplace=True)
df_23.rename(columns={'B365>2.5' : 'over2.5', 'B365<2.5' : 'under2.5'}, inplace=True)
df_24.rename(columns={'B365>2.5' : 'over2.5', 'B365<2.5' : 'under2.5'}, inplace=True)
fb_data = pd.concat([df_17, df_18, df_19, df_20, df_21, df_22, df_23, df_24])
fb_data.columns = fb_data.columns.str.lower()
fb_data
# Out:
#           date        hometeam        awayteam  b365h  b365d  b365a  over2.5  \
# 0   11/08/2017         Arsenal       Leicester   1.53    4.5   6.50     1.61
# 1   12/08/2017        Brighton        Man City  11.00    5.5   1.33     1.63
# 2   12/08/2017         Chelsea         Burnley   1.25    6.5  15.00     1.66
# 3   12/08/2017  Crystal Palace    Huddersfield   1.83    3.6   5.00     2.11
# 4   12/08/2017         Everton           Stoke   1.70    3.8   5.75     2.08
# ..         ...             ...             ...    ...    ...    ...      ...
# 95  02/11/2024     Southampton         Everton   2.63    3.4   2.63     1.84
# 96  02/11/2024          Wolves  Crystal Palace   2.50    3.4   2.88     1.90
# 97  03/11/2024       Tottenham     Aston Villa   1.91    4.0   3.60     1.44
# 98  03/11/2024      Man United         Chelsea   2.60    3.5   2.60     1.44
# 99  04/11/2024          Fulham       Brentford   2.00    3.7   3.50     1.67
#
#     under2.5
# 0       2.32
# 1       2.27
# ...

# %%
fb_data['date'] = pd.to_datetime(fb_data['date'], format='%d/%m/%Y')
fb_data
# Out:
#          date        hometeam        awayteam  b365h  b365d  b365a  over2.5  \
# 0  2017-08-11         Arsenal       Leicester   1.53    4.5   6.50     1.61
# 1  2017-08-12        Brighton        Man City  11.00    5.5   1.33     1.63
# 2  2017-08-12         Chelsea         Burnley   1.25    6.5  15.00     1.66
# 3  2017-08-12  Crystal Palace    Huddersfield   1.83    3.6   5.00     2.11
# 4  2017-08-12         Everton           Stoke   1.70    3.8   5.75     2.08
# ..        ...             ...             ...    ...    ...    ...      ...
# 95 2024-11-02     Southampton         Everton   2.63    3.4   2.63     1.84
# 96 2024-11-02          Wolves  Crystal Palace   2.50    3.4   2.88     1.90
# 97 2024-11-03       Tottenham     Aston Villa   1.91    4.0   3.60     1.44
# 98 2024-11-03      Man United         Chelsea   2.60    3.5   2.60     1.44
# 99 2024-11-04          Fulham       Brentford   2.00    3.7   3.50     1.67
#
#     under2.5
# 0       2.32
# 1       2.27
# ...

# %%
team_name_map = {
    'Man City' : 'Manchester City',
    'Nott\'m Forest' : 'Nottingham Forest',
    'Tottenham' : 'Tottenham Hotspur',
    'Brighton' : 'Brighton and Hove Albion',
    'Newcastle' : 'Newcastle United',
    'Man United' : 'Manchester United',
    'West Ham' : 'West Ham United',
    'Leicester' : 'Leicester City',
    'Ipswich' : 'Ipswich Town',
    'Wolves' : 'Wolverhampton Wanderers',
    'Luton' : 'Luton Town',
    'Leeds' : 'Leeds United',
    'Norwich' : 'Norwich City',
    'West Brom' : 'West Bromwich Albion',
    'Cardiff' : 'Cardiff City',
    'Huddersfield' : 'Huddersfield Town',
    'Swansea' : 'Swansea City',
    'Stoke' : 'Stoke City',
    'Manchester Utd' : 'Manchester United',
    'Nott\'ham Forest' : 'Nottingham Forest',
    'Newcastle Utd' : 'Newcastle United',
    'Sheffield Utd' : 'Sheffield United'
}

# %%
fb_data['hometeam'] = fb_data['hometeam'].replace(team_name_map)
fb_data['awayteam'] = fb_data['awayteam'].replace(team_name_map)
fbref_data['opponent'] = fbref_data['opponent'].replace(team_name_map)
fb_data
# Out:
#          date                  hometeam           awayteam  b365h  b365d  \
# 0  2017-08-11                   Arsenal     Leicester City   1.53    4.5
# 1  2017-08-12  Brighton and Hove Albion    Manchester City  11.00    5.5
# 2  2017-08-12                   Chelsea            Burnley   1.25    6.5
# 3  2017-08-12            Crystal Palace  Huddersfield Town   1.83    3.6
# 4  2017-08-12                   Everton         Stoke City   1.70    3.8
# ..        ...                       ...                ...    ...    ...
# 95 2024-11-02               Southampton            Everton   2.63    3.4
# 96 2024-11-02   Wolverhampton Wanderers     Crystal Palace   2.50    3.4
# 97 2024-11-03         Tottenham Hotspur        Aston Villa   1.91    4.0
# 98 2024-11-03         Manchester United            Chelsea   2.60    3.5
# 99 2024-11-04                    Fulham          Brentford   2.00    3.7
#
#     b365a  over2.5  under2.5
# 0    6.50     1.61      2.32
# 1    1.33     1.63      2.27
# ...

# %%
fb_data[fb_data['hometeam'] == 'Nottingham Forest'].head()
# Out:
#          date           hometeam           awayteam  b365h  b365d  b365a  \
# 17 2022-08-14  Nottingham Forest    West Ham United   4.20    3.6   1.85
# 39 2022-08-28  Nottingham Forest  Tottenham Hotspur   7.00    4.6   1.44
# 54 2022-09-03  Nottingham Forest        Bournemouth   1.95    3.5   3.80
# 61 2022-09-16  Nottingham Forest             Fulham   2.75    3.3   2.62
# 86 2022-10-10  Nottingham Forest        Aston Villa   3.30    3.4   2.20
#
#     over2.5  under2.5
# 17     1.92      1.98
# 39     1.72      2.10
# 54     2.10      1.72
# 61     1.93      1.97
# 86     2.03      1.87

# %%
merged_home = pd.merge(fbref_data, fb_data, left_on=['date', 'team'], right_on=['date', 'hometeam'], how='inner')
merged_away = pd.merge(fbref_data, fb_data, left_on=['date', 'team'], right_on=['date', 'awayteam'], how='inner')
merged_data = pd.concat([merged_home, merged_away], ignore_index=True)
merged_data
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 1    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 2    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# 3    2024-10-20  16:30  Premier League   Matchweek 8  Sun  Home      W  2.0
# 4    2024-11-02  15:00  Premier League  Matchweek 10  Sat  Home      W  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5515 2018-03-03  15:00  Premier League  Matchweek 29  Sat  Away      L  0.0
# 5516 2018-03-17  15:00  Premier League  Matchweek 31  Sat  Away      L  1.0
# 5517 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5518 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5519 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
merged_data[merged_data['team'] == 'Ipswich Town']
# Out:
#            date   time            comp         round  day venue result   gf  \
# 85   2024-08-17  12:30  Premier League   Matchweek 1  Sat  Home      L  0.0
# 86   2024-08-31  15:00  Premier League   Matchweek 3  Sat  Home      D  1.0
# 87   2024-09-29  14:00  Premier League   Matchweek 6  Sun  Home      D  2.0
# 88   2024-10-19  15:00  Premier League   Matchweek 8  Sat  Home      L  0.0
# 89   2024-11-02  15:00  Premier League  Matchweek 10  Sat  Home      D  1.0
# 2845 2024-08-24  15:00  Premier League   Matchweek 2  Sat  Away      L  1.0
# 2846 2024-09-14  15:00  Premier League   Matchweek 4  Sat  Away      D  0.0
# 2847 2024-09-21  15:00  Premier League   Matchweek 5  Sat  Away      D  1.0
# 2848 2024-10-05  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 2849 2024-10-26  15:00  Premier League   Matchweek 9  Sat  Away      L  3.0
#
#        ga                  opponent  ...  aerial duels lost     season  \
# ...

# %%
merged_data.to_csv('./data/raw_data.csv', index=False)
