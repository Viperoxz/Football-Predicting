# %%
import pandas as pd

# %%
fbref_data = pd.read_csv('../../data/raw/fbref/fbref_matches.csv')
fbref_data.columns = fbref_data.columns.str.lower()
fbref_data['date'] = pd.to_datetime(fbref_data['date'])
fbref_data['round'] = fbref_data['round'].str.replace('Matchweek ', '').astype(int)
fbref_data = fbref_data[fbref_data['season'].isin(['2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025'])]
fbref_data
# Out:
#            date   time            comp  round  day venue result   gf   ga  \
# 0    2024-08-17  12:30  Premier League      1  Sat  Away      W  2.0  0.0
# 1    2024-08-25  16:30  Premier League      2  Sun  Home      W  2.0  0.0
# 2    2024-09-01  16:00  Premier League      3  Sun  Away      W  3.0  0.0
# 3    2024-09-14  15:00  Premier League      4  Sat  Home      L  0.0  1.0
# 4    2024-09-21  15:00  Premier League      5  Sat  Home      W  3.0  0.0
# ...         ...    ...             ...    ...  ...   ...    ...  ...  ...
# 3235 2021-05-02  19:15  Premier League     34  Sun  Away      L  0.0  4.0
# 3236 2021-05-08  15:00  Premier League     35  Sat  Home      L  0.0  2.0
# 3237 2021-05-16  19:00  Premier League     36  Sun  Away      W  1.0  0.0
# 3238 2021-05-19  18:00  Premier League     37  Wed  Away      L  0.0  1.0
# 3239 2021-05-23  16:00  Premier League     38  Sun  Home      W  1.0  0.0
#
#              opponent  ...  performance int  performance tklw  \
# 0        Ipswich Town  ...              5.0               4.0
# 1           Brentford  ...              7.0              10.0
# 2      Manchester Utd  ...             10.0              17.0
# 3     Nott'ham Forest  ...             11.0               8.0
# 4         Bournemouth  ...              6.0              14.0
# ...               ...  ...              ...               ...
# 3235        Tottenham  ...              8.0               7.0
# 3236   Crystal Palace  ...              9.0              13.0
# 3237          Everton  ...              8.0               7.0
# 3238    Newcastle Utd  ...              4.0              10.0
# 3239          Burnley  ...              5.0              13.0
#
#       performance pkwon  performance pkcon performance og performance recov  \
# 0                   0.0                0.0            0.0              40.0
# 1                   0.0                0.0            0.0              47.0
# 2                   0.0                0.0            0.0              53.0
# 3                   0.0                0.0            0.0              47.0
# 4                   0.0                0.0            0.0              44.0
# ...                 ...                ...            ...               ...
# 3235                0.0                0.0            0.0              51.0
# 3236                0.0                0.0            0.0              52.0
# 3237                0.0                0.0            0.0              55.0
# 3238                0.0                0.0            0.0              41.0
# 3239                0.0                0.0            0.0              55.0
#
#      aerial duels won aerial duels lost     season              team
# 0                18.0              11.0  2024-2025         Liverpool
# 1                 6.0               8.0  2024-2025         Liverpool
# 2                13.0               5.0  2024-2025         Liverpool
# 3                21.0              12.0  2024-2025         Liverpool
# 4                 9.0               6.0  2024-2025         Liverpool
# ...               ...               ...        ...               ...
# 3235              8.0              13.0  2020-2021  Sheffield United
# 3236             15.0              19.0  2020-2021  Sheffield United
# 3237             12.0              27.0  2020-2021  Sheffield United
# 3238             14.0              16.0  2020-2021  Sheffield United
# 3239             39.0              44.0  2020-2021  Sheffield United
#
# [3240 rows x 135 columns]

# %%
fbref_data['noscale_gf'] = fbref_data['gf']
fbref_data['noscale_ga'] = fbref_data['ga']

# %%
features_to_use = ['noscale_gf', 'noscale_ga', 'gf', 'ga', 'xg', 'xga', 'standard sot', 'kp', 'xa', 'poss_x', 'touches att pen', 'carries prgdist', 'progressive passing dist', 'tackles tklw', 
                   'challenges tkl%', 'saves']
fbref_data = fbref_data[['team', 'opponent', 'date', 'season', 'round', 'venue'] + features_to_use]

# %%
from sklearn.preprocessing import MinMaxScaler

features_to_getform = [col for col in features_to_use if col not in ['noscale_gf', 'noscale_ga']]
scaler = MinMaxScaler()
fbref_data[features_to_getform] = scaler.fit_transform(fbref_data[features_to_getform])
fbref_data.head(10)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\247149926.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_data[features_to_getform] = scaler.fit_transform(fbref_data[features_to_getform])
#         team         opponent       date     season  round venue  noscale_gf  \
# 0  Liverpool     Ipswich Town 2024-08-17  2024-2025      1  Away         2.0
# 1  Liverpool        Brentford 2024-08-25  2024-2025      2  Home         2.0
# 2  Liverpool   Manchester Utd 2024-09-01  2024-2025      3  Away         3.0
# 3  Liverpool  Nott'ham Forest 2024-09-14  2024-2025      4  Home         0.0
# 4  Liverpool      Bournemouth 2024-09-21  2024-2025      5  Home         3.0
# 5  Liverpool           Wolves 2024-09-28  2024-2025      6  Away         2.0
# 6  Liverpool   Crystal Palace 2024-10-05  2024-2025      7  Away         1.0
# 7  Liverpool          Chelsea 2024-10-20  2024-2025      8  Home         2.0
# 8  Liverpool          Arsenal 2024-10-27  2024-2025      9  Away         2.0
# 9  Liverpool         Brighton 2024-11-02  2024-2025     10  Home         2.0
#
#    noscale_ga        gf        ga  ...  standard sot        kp        xa  \
# 0         0.0  0.222222  0.000000  ...        0.3125  0.400000  0.621622
# 1         0.0  0.222222  0.000000  ...        0.5000  0.566667  0.405405
# 2         0.0  0.333333  0.000000  ...        0.1875  0.300000  0.270270
# 3         1.0  0.000000  0.111111  ...        0.3125  0.433333  0.351351
# 4         0.0  0.333333  0.000000  ...        0.7500  0.600000  0.243243
# 5         1.0  0.222222  0.111111  ...        0.3125  0.233333  0.297297
# 6         0.0  0.111111  0.000000  ...        0.2500  0.533333  0.378378
# 7         1.0  0.222222  0.111111  ...        0.2500  0.200000  0.054054
# 8         2.0  0.222222  0.222222  ...        0.2500  0.200000  0.270270
# 9         1.0  0.222222  0.111111  ...        0.5000  0.400000  0.243243
#
#      poss_x  touches att pen  carries prgdist  progressive passing dist  \
# 0  0.687500         0.484211         0.370861                  0.577814
# 1  0.687500         0.421053         0.472091                  0.653857
# 2  0.453125         0.273684         0.351939                  0.387844
# 3  0.781250         0.326316         0.527909                  0.630962
# 4  0.625000         0.294737         0.473510                  0.677024
# 5  0.578125         0.368421         0.329707                  0.502589
# 6  0.781250         0.273684         0.488174                  0.693922
# 7  0.390625         0.157895         0.172658                  0.310439
# 8  0.578125         0.242105         0.211447                  0.384301
# 9  0.484375         0.294737         0.300851                  0.448351
#
#    tackles tklw  challenges tkl%     saves
# 0      0.148148            0.625  0.153846
# 1      0.370370            0.684  0.153846
# 2      0.629630            0.619  0.230769
# 3      0.296296            0.455  0.153846
# 4      0.518519            0.522  0.461538
# 5      0.333333            0.364  0.153846
# 6      0.222222            0.636  0.384615
# 7      0.666667            0.630  0.076923
# 8      0.333333            0.500  0.076923
# 9      0.703704            0.680  0.307692
#
# [10 rows x 22 columns]

# %%
fbref_data = fbref_data.sort_values(['team', 'date']).reset_index(drop=True)
# def get_form(df, features):
#     result = df.copy()
#     weights = [0.1, 0.2, 0.3, 0.4] 

#     for feature in features:
#         result[f'form_{feature}'] = (
#             df.groupby('team')[feature]
#             .apply(lambda x: x.shift(1)  
#                    .rolling(window=4, min_periods=1)  
#                    .apply(lambda y: sum(w * v for w, v in zip(weights[:len(y)], y)), raw=True))  
#             .reset_index(level=0, drop=True)
#         )
#         result[f'form_{feature}'] = result[f'form_{feature}'].combine_first(df[feature])

#     return result


# fbref_data = get_form(fbref_data, features_to_getform)
fbref_data
# Out:
#                          team         opponent       date     season  round  \
# 0                     Arsenal           Fulham 2020-09-12  2020-2021      1
# 1                     Arsenal         West Ham 2020-09-19  2020-2021      2
# 2                     Arsenal        Liverpool 2020-09-28  2020-2021      3
# 3                     Arsenal    Sheffield Utd 2020-10-04  2020-2021      4
# 4                     Arsenal  Manchester City 2020-10-17  2020-2021      5
# ...                       ...              ...        ...        ...    ...
# 3235  Wolverhampton Wanderers        Liverpool 2024-09-28  2024-2025      6
# 3236  Wolverhampton Wanderers        Brentford 2024-10-05  2024-2025      7
# 3237  Wolverhampton Wanderers  Manchester City 2024-10-20  2024-2025      8
# 3238  Wolverhampton Wanderers         Brighton 2024-10-26  2024-2025      9
# 3239  Wolverhampton Wanderers   Crystal Palace 2024-11-02  2024-2025     10
#
#      venue  noscale_gf  noscale_ga        gf        ga  ...  \
# 0     Away         3.0         0.0  0.333333  0.000000  ...
# 1     Home         2.0         1.0  0.222222  0.111111  ...
# 2     Away         1.0         3.0  0.111111  0.333333  ...
# 3     Home         2.0         1.0  0.222222  0.111111  ...
# 4     Away         0.0         1.0  0.000000  0.111111  ...
# ...    ...         ...         ...       ...       ...  ...
# 3235  Home         1.0         2.0  0.111111  0.222222  ...
# 3236  Away         3.0         5.0  0.333333  0.555556  ...
# 3237  Home         1.0         2.0  0.111111  0.222222  ...
# 3238  Away         2.0         2.0  0.222222  0.222222  ...
# 3239  Home         2.0         2.0  0.222222  0.222222  ...
#
#       form_standard sot   form_kp   form_xa  form_poss_x  \
# 0               0.31250  0.266667  0.243243     0.562500
# 1               0.18750  0.200000  0.405405     0.687500
# 2               0.18750  0.100000  0.135135     0.250000
# 3               0.31250  0.200000  0.135135     0.718750
# 4               0.25000  0.176667  0.200000     0.556250
# ...                 ...       ...       ...          ...
# 3235            0.24375  0.253333  0.167568     0.454688
# 3236            0.22500  0.230000  0.113514     0.448437
# 3237            0.28750  0.320000  0.148649     0.503125
# 3238            0.22500  0.243333  0.108108     0.339063
# 3239            0.30625  0.303333  0.140541     0.378125
#
#       form_touches att pen  form_carries prgdist  \
# 0                 0.273684              0.538789
# 1                 0.294737              0.629612
# 2                 0.105263              0.231315
# 3                 0.147368              0.671712
# 4                 0.176842              0.517881
# ...                    ...                   ...
# 3235              0.200000              0.319300
# 3236              0.193684              0.353784
# 3237              0.248421              0.341580
# 3238              0.170526              0.259650
# 3239              0.214737              0.283775
#
#       form_progressive passing dist  form_tackles tklw  form_challenges tkl%  \
# 0                          0.490052           0.185185                0.5000
# 1                          0.498228           0.185185                0.5450
# 2                          0.183701           0.222222                0.3330
# 3                          0.573181           0.148148                0.3000
# 4                          0.433034           0.181481                0.3789
# ...                             ...                ...                   ...
# 3235                       0.323467           0.429630                0.4900
# 3236                       0.334424           0.418519                0.5494
# 3237                       0.345326           0.462963                0.5868
# 3238                       0.250313           0.474074                0.5847
# 3239                       0.302180           0.474074                0.5589
#
#       form_saves
# 0       0.153846
# 1       0.076923
# 2       0.384615
# 3       0.076923
# 4       0.176923
# ...          ...
# 3235    0.169231
# 3236    0.215385
# 3237    0.338462
# 3238    0.376923
# 3239    0.376923
#
# [3240 rows x 36 columns]

# %%
fbref_data.drop(columns=[col for col in features_to_getform], inplace=True)

# %%
fbref_data.rename(columns={'noscale_gf': 'gf', 'noscale_ga': 'ga'}, inplace=True)

# %%
fbref_data.columns
# Out:
# Index(['team', 'opponent', 'date', 'season', 'round', 'venue', 'gf', 'ga',
#        'form_gf', 'form_ga', 'form_xg', 'form_xga', 'form_standard sot',
#        'form_kp', 'form_xa', 'form_poss_x', 'form_touches att pen',
#        'form_carries prgdist', 'form_progressive passing dist',
#        'form_tackles tklw', 'form_challenges tkl%', 'form_saves'],
#       dtype='object')

# %%
test_df = fbref_data[['team', 'opponent', 'date', 'season', 'round', 'venue', 'form_gf', 'form_ga', 'gf', 'ga']]
test_df[(test_df['team'] == 'Manchester United')]
# Out:
#                    team        opponent       date     season  round venue  \
# 2030  Manchester United  Crystal Palace 2020-09-19  2020-2021      2  Home
# 2031  Manchester United        Brighton 2020-09-26  2020-2021      3  Away
# 2032  Manchester United       Tottenham 2020-10-04  2020-2021      4  Home
# 2033  Manchester United   Newcastle Utd 2020-10-17  2020-2021      5  Away
# 2034  Manchester United         Chelsea 2020-10-24  2020-2021      6  Home
# ...                 ...             ...        ...        ...    ...   ...
# 2187  Manchester United       Tottenham 2024-09-29  2024-2025      6  Home
# 2188  Manchester United     Aston Villa 2024-10-06  2024-2025      7  Away
# 2189  Manchester United       Brentford 2024-10-19  2024-2025      8  Home
# 2190  Manchester United        West Ham 2024-10-27  2024-2025      9  Away
# 2191  Manchester United         Chelsea 2024-11-03  2024-2025     10  Home
#
#        form_gf   form_ga   gf   ga
# 2030  0.111111  0.333333  1.0  3.0
# 2031  0.333333  0.222222  3.0  2.0
# 2032  0.111111  0.666667  1.0  6.0
# 2033  0.444444  0.111111  4.0  1.0
# 2034  0.288889  0.322222  0.0  0.0
# ...        ...       ...  ...  ...
# 2187  0.111111  0.088889  0.0  3.0
# 2188  0.066667  0.166667  0.0  0.0
# 2189  0.033333  0.100000  2.0  1.0
# 2190  0.088889  0.111111  1.0  2.0
# 2191  0.111111  0.155556  1.0  1.0
#
# [162 rows x 10 columns]

# %%
fbref_data.columns
# Out:
# Index(['team', 'opponent', 'date', 'season', 'round', 'venue', 'gf', 'ga',
#        'form_gf', 'form_ga', 'form_xg', 'form_xga', 'form_standard sot',
#        'form_kp', 'form_xa', 'form_poss_x', 'form_touches att pen',
#        'form_carries prgdist', 'form_progressive passing dist',
#        'form_tackles tklw', 'form_challenges tkl%', 'form_saves'],
#       dtype='object')

# %%
fbref_data_home = fbref_data[fbref_data['venue'] == 'Home']
fbref_data_away = fbref_data[fbref_data['venue'] == 'Away']

# %%
df_21 = pd.read_csv('../../data/raw/fbdata/20_21.csv')
df_22 = pd.read_csv('../../data/raw/fbdata/21_22.csv')
df_23 = pd.read_csv('../../data/raw/fbdata/22_23.csv')
df_24 = pd.read_csv('../../data/raw/fbdata/23_24.csv')
df_25 = pd.read_csv('../../data/raw/fbdata/24_25.csv')

df_21 = df_21[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'FTR']]
df_22 = df_22[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'FTR']]
df_23 = df_23[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'FTR']]
df_24 = df_24[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'FTR']]
df_25 = df_25[['Date', 'HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A', 'FTR']]
print(len(df_21), len(df_22), len(df_23), len(df_24), len(df_25))
# Out:
# 380 380 380 380 100

# %%
fbref_data['team'].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford',
#        'Brighton and Hove Albion', 'Burnley', 'Chelsea', 'Crystal Palace',
#        'Everton', 'Fulham', 'Ipswich Town', 'Leeds United',
#        'Leicester City', 'Liverpool', 'Luton Town', 'Manchester City',
#        'Manchester United', 'Newcastle United', 'Norwich City',
#        'Nottingham Forest', 'Sheffield United', 'Southampton',
#        'Tottenham Hotspur', 'Watford', 'West Bromwich Albion',
#        'West Ham United', 'Wolverhampton Wanderers'], dtype=object)

# %%
fb_data = pd.concat([df_21, df_22, df_23, df_24, df_25])
fb_data.columns = fb_data.columns.str.lower()
fb_data
# Out:
#           date        hometeam        awayteam  b365h  b365d  b365a ftr
# 0   12/09/2020          Fulham         Arsenal   6.00   4.33   1.53   A
# 1   12/09/2020  Crystal Palace     Southampton   3.10   3.25   2.37   H
# 2   12/09/2020       Liverpool           Leeds   1.28   6.00   9.50   H
# 3   12/09/2020        West Ham       Newcastle   2.15   3.40   3.40   A
# 4   13/09/2020       West Brom       Leicester   3.80   3.60   1.95   A
# ..         ...             ...             ...    ...    ...    ...  ..
# 95  02/11/2024     Southampton         Everton   2.63   3.40   2.63   H
# 96  02/11/2024          Wolves  Crystal Palace   2.50   3.40   2.88   D
# 97  03/11/2024       Tottenham     Aston Villa   1.91   4.00   3.60   H
# 98  03/11/2024      Man United         Chelsea   2.60   3.50   2.60   D
# 99  04/11/2024          Fulham       Brentford   2.00   3.70   3.50   H
#
# [1620 rows x 7 columns]

# %%
fb_data['hometeam'].unique()
# Out:
# array(['Fulham', 'Crystal Palace', 'Liverpool', 'West Ham', 'West Brom',
#        'Tottenham', 'Brighton', 'Sheffield United', 'Everton', 'Leeds',
#        'Man United', 'Arsenal', 'Southampton', 'Newcastle', 'Chelsea',
#        'Leicester', 'Aston Villa', 'Wolves', 'Burnley', 'Man City',
#        'Brentford', 'Watford', 'Norwich', 'Bournemouth', "Nott'm Forest",
#        'Luton', 'Ipswich'], dtype=object)

# %%
fbref_team_map = {
    'Liverpool': 'LIV',
    'Manchester City': 'MCI',
    'Nottingham Forest': 'NFO',
    'Chelsea': 'CHE',
    'Arsenal': 'ARS',
    'Aston Villa': 'AVL',
    'Tottenham Hotspur': 'TOT',
    'Brighton and Hove Albion': 'BHA',
    'Fulham': 'FUL',
    'Bournemouth': 'BOU',
    'Newcastle United': 'NEW',
    'Brentford': 'BRE',
    'Manchester United': 'MUN',
    'West Ham United': 'WHU',
    'Leicester City': 'LEI',
    'Everton': 'EVE',
    'Crystal Palace': 'CRY',
    'Ipswich Town': 'IPS',
    'Southampton': 'SOU',
    'Wolverhampton Wanderers': 'WOL',
    'Luton Town': 'LUT',
    'Burnley': 'BUR',
    'Sheffield United': 'SHU',
    'Leeds United': 'LEE',
    'Watford': 'WAT',
    'Norwich City': 'NOR',
    'West Bromwich Albion': 'WBA'
}

fbdata_team_map = {
    'Fulham': 'FUL',
    'Crystal Palace': 'CRY',
    'Liverpool': 'LIV',
    'West Ham': 'WHU',
    'West Brom': 'WBA',
    'Tottenham': 'TOT',
    'Brighton': 'BHA',
    'Sheffield United': 'SHU',
    'Everton': 'EVE',
    'Leeds': 'LEE',
    'Man United': 'MUN',
    'Arsenal': 'ARS',
    'Southampton': 'SOU',
    'Newcastle': 'NEW',
    'Chelsea': 'CHE',
    'Leicester': 'LEI',
    'Aston Villa': 'AVL',
    'Wolves': 'WOL',
    'Burnley': 'BUR',
    'Man City': 'MCI',
    'Brentford': 'BRE',
    'Watford': 'WAT',
    'Norwich': 'NOR',
    'Bournemouth': 'BOU',
    "Nott'm Forest": 'NFO',
    'Luton': 'LUT',
    'Ipswich': 'IPS'
}

# %%
fbref_data_home['team'] = fbref_data_home['team'].map(fbref_team_map)
fbref_data_home['opponent'] = fbref_data_home['opponent'].map(fbref_team_map)
fbref_data_away['team'] = fbref_data_away['team'].map(fbref_team_map)
fbref_data_away['opponent'] = fbref_data_away['opponent'].map(fbref_team_map)

fb_data['hometeam'] = fb_data['hometeam'].map(fbdata_team_map)
fb_data['awayteam'] = fb_data['awayteam'].map(fbdata_team_map)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\304674382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_data_home['team'] = fbref_data_home['team'].map(fbref_team_map)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\304674382.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_data_home['opponent'] = fbref_data_home['opponent'].map(fbref_team_map)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\304674382.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_data_away['team'] = fbref_data_away['team'].map(fbref_team_map)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\304674382.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fbref_data_away['opponent'] = fbref_data_away['opponent'].map(fbref_team_map)

# %%
fb_data['date'] = pd.to_datetime(fb_data['date'], format='%d/%m/%Y')
fb_data
# Out:
#          date hometeam awayteam  b365h  b365d  b365a ftr
# 0  2020-09-12      FUL      ARS   6.00   4.33   1.53   A
# 1  2020-09-12      CRY      SOU   3.10   3.25   2.37   H
# 2  2020-09-12      LIV      LEE   1.28   6.00   9.50   H
# 3  2020-09-12      WHU      NEW   2.15   3.40   3.40   A
# 4  2020-09-13      WBA      LEI   3.80   3.60   1.95   A
# ..        ...      ...      ...    ...    ...    ...  ..
# 95 2024-11-02      SOU      EVE   2.63   3.40   2.63   H
# 96 2024-11-02      WOL      CRY   2.50   3.40   2.88   D
# 97 2024-11-03      TOT      AVL   1.91   4.00   3.60   H
# 98 2024-11-03      MUN      CHE   2.60   3.50   2.60   D
# 99 2024-11-04      FUL      BRE   2.00   3.70   3.50   H
#
# [1620 rows x 7 columns]

# %%
scaler = MinMaxScaler()
fb_data[['b365h', 'b365d', 'b365a']] = scaler.fit_transform(fb_data[['b365h', 'b365d', 'b365a']])
fb_data.head(10)
# Out:
#         date hometeam awayteam     b365h     b365d     b365a ftr
# 0 2020-09-12      FUL      ARS  0.275362  0.150000  0.013999   A
# 1 2020-09-12      CRY      SOU  0.113712  0.044118  0.044149   H
# 2 2020-09-12      LIV      LEE  0.012263  0.313725  0.300072   H
# 3 2020-09-12      WHU      NEW  0.060758  0.058824  0.081120   A
# 4 2020-09-13      WBA      LEI  0.152731  0.078431  0.029074   A
# 5 2020-09-13      TOT      EVE  0.042921  0.078431  0.114501   A
# 6 2020-09-14      BHA      CHE  0.219621  0.150000  0.016870   A
# 7 2020-09-14      SHU      WOL  0.122074  0.029412  0.044149   A
# 8 2020-09-19      EVE      WBA  0.024526  0.137255  0.192391   H
# 9 2020-09-19      LEE      FUL  0.030658  0.107843  0.165470   H

# %%
fbref_data_home['team'].unique(), fbref_data_away['team'].unique(), fb_data['hometeam'].unique()
# Out:
# (array(['ARS', 'AVL', 'BOU', 'BRE', 'BHA', 'BUR', 'CHE', 'CRY', 'EVE',
#         'FUL', 'IPS', 'LEE', 'LEI', 'LIV', 'LUT', 'MCI', 'MUN', 'NEW',
#         'NOR', 'NFO', 'SHU', 'SOU', 'TOT', 'WAT', 'WBA', 'WHU', 'WOL'],
#        dtype=object),
#  array(['ARS', 'AVL', 'BOU', 'BRE', 'BHA', 'BUR', 'CHE', 'CRY', 'EVE',
#         'FUL', 'IPS', 'LEE', 'LEI', 'LIV', 'LUT', 'MCI', 'MUN', 'NEW',
#         'NOR', 'NFO', 'SHU', 'SOU', 'TOT', 'WAT', 'WBA', 'WHU', 'WOL'],
#        dtype=object),
#  array(['FUL', 'CRY', 'LIV', 'WHU', 'WBA', 'TOT', 'BHA', 'SHU', 'EVE',
#         'LEE', 'MUN', 'ARS', 'SOU', 'NEW', 'CHE', 'LEI', 'AVL', 'WOL',
#         'BUR', 'MCI', 'BRE', 'WAT', 'NOR', 'BOU', 'NFO', 'LUT', 'IPS'],
#        dtype=object))

# %%
fbref_data_home.isnull().sum()
# Out:
# team                               0
# opponent                         586
# date                               0
# season                             0
# round                              0
# venue                              0
# gf                                 0
# ga                                 0
# form_gf                            0
# form_ga                            0
# form_xg                            0
# form_xga                           0
# form_standard sot                  0
# form_kp                            0
# form_xa                            0
# form_poss_x                        0
# form_touches att pen               0
# form_carries prgdist               0
# form_progressive passing dist      0
# form_tackles tklw                  0
# form_challenges tkl%               0
# form_saves                         0
# dtype: int64

# %%
fbref_data_away.isnull().sum()
# Out:
# team                               0
# opponent                         586
# date                               0
# season                             0
# round                              0
# venue                              0
# gf                                 0
# ga                                 0
# form_gf                            0
# form_ga                            0
# form_xg                            0
# form_xga                           0
# form_standard sot                  0
# form_kp                            0
# form_xa                            0
# form_poss_x                        0
# form_touches att pen               0
# form_carries prgdist               0
# form_progressive passing dist      0
# form_tackles tklw                  0
# form_challenges tkl%               0
# form_saves                         0
# dtype: int64

# %%
def fill_na_opponent(df, type):
    opp = 'awayteam' if type == 'hometeam' else 'hometeam'
    for index, row in df[df['opponent'].isnull()].iterrows():
        team = row['team']
        match_date = row['date']
        possible_opponents = fb_data[(fb_data['date'] == match_date) & 
                                    (fb_data[type] == team)]
        if not possible_opponents.empty:
            opponent = possible_opponents.iloc[0][opp]
            df.at[index, 'opponent'] = opponent
    return df

# %%
fbref_data_home =  fill_na_opponent(fbref_data_home, 'hometeam')
fbref_data_away =  fill_na_opponent(fbref_data_away, 'awayteam')

# %%
fbref_data_home.columns
# Out:
# Index(['team', 'opponent', 'date', 'season', 'round', 'venue', 'gf', 'ga',
#        'form_gf', 'form_ga', 'form_xg', 'form_xga', 'form_standard sot',
#        'form_kp', 'form_xa', 'form_poss_x', 'form_touches att pen',
#        'form_carries prgdist', 'form_progressive passing dist',
#        'form_tackles tklw', 'form_challenges tkl%', 'form_saves'],
#       dtype='object')

# %%
base_features = ['team', 'opponent', 'date', 'season', 'round', 'venue', 'gf', 'ga']
fbref_data_home = fbref_data_home.rename(columns=lambda x: f"h_{x}" if x not in base_features else x)
fbref_data_away = fbref_data_away.rename(columns=lambda x: f"a_{x}" if x not in base_features else x)

merged_data = fbref_data_home.merge(
    fbref_data_away,
    left_on=['date', 'opponent'],  
    right_on=['date', 'team'],    
    suffixes=('', '_away')
)

cols_to_drop = [col + '_away' for col in base_features if col != 'date']
merged_data.drop(columns=cols_to_drop, inplace=True)
merged_data
# Out:
#      team opponent       date     season  round venue   gf   ga  h_form_gf  \
# 0     ARS      WHU 2020-09-19  2020-2021      2  Home  2.0  1.0   0.222222
# 1     ARS      SHU 2020-10-04  2020-2021      4  Home  2.0  1.0   0.222222
# 2     ARS      LEI 2020-10-25  2020-2021      6  Home  0.0  1.0   0.111111
# 3     ARS      AVL 2020-11-08  2020-2021      8  Home  0.0  3.0   0.066667
# 4     ARS      WOL 2020-11-29  2020-2021     10  Home  1.0  2.0   0.022222
# ...   ...      ...        ...        ...    ...   ...  ...  ...        ...
# 1615  WOL      CHE 2024-08-25  2024-2025      2  Home  2.0  6.0   0.033333
# 1616  WOL      NEW 2024-09-15  2024-2025      4  Home  1.0  2.0   0.111111
# 1617  WOL      LIV 2024-09-28  2024-2025      6  Home  1.0  2.0   0.122222
# 1618  WOL      MCI 2024-10-20  2024-2025      8  Home  1.0  2.0   0.200000
# 1619  WOL      CRY 2024-11-02  2024-2025     10  Home  2.0  2.0   0.200000
#
#       h_form_ga  ...  a_form_standard sot  a_form_kp  a_form_xa  \
# 0      0.111111  ...              0.12500   0.300000   0.189189
# 1      0.111111  ...              0.12500   0.133333   0.054054
# 2      0.155556  ...              0.21250   0.180000   0.091892
# 3      0.066667  ...              0.40000   0.390000   0.200000
# 4      0.111111  ...              0.34375   0.376667   0.172973
# ...         ...  ...                  ...        ...        ...
# 1615   0.277778  ...              0.29375   0.363333   0.254054
# 1616   0.311111  ...              0.22500   0.266667   0.283784
# 1617   0.288889  ...              0.48125   0.486667   0.297297
# 1618   0.377778  ...              0.46875   0.550000   0.424324
# 1619   0.288889  ...              0.36875   0.346667   0.140541
#
#       a_form_poss_x  a_form_touches att pen  a_form_carries prgdist  \
# 0          0.312500                0.200000                0.293283
# 1          0.281250                0.157895                0.231315
# 2          0.546875                0.215789                0.362252
# 3          0.465625                0.314737                0.254210
# 4          0.484375                0.257895                0.357616
# ...             ...                     ...                     ...
# 1615       0.550000                0.283158                0.347635
# 1616       0.367188                0.208421                0.201703
# 1617       0.643750                0.312632                0.465374
# 1618       0.696875                0.449474                0.630842
# 1619       0.353125                0.206316                0.217219
#
#       a_form_progressive passing dist  a_form_tackles tklw  \
# 0                            0.307441             0.185185
# 1                            0.192968             0.148148
# 2                            0.413355             0.296296
# 3                            0.359444             0.251852
# 4                            0.420660             0.355556
# ...                               ...                  ...
# 1615                         0.538757             0.451852
# 1616                         0.301145             0.392593
# 1617                         0.603053             0.459259
# 1618                         0.424203             0.281481
# 1619                         0.326083             0.544444
#
#       a_form_challenges tkl%  a_form_saves
# 0                     0.3330      0.076923
# 1                     0.3330      0.230769
# 2                     0.4307      0.230769
# 3                     0.4148      0.261538
# 4                     0.4561      0.092308
# ...                      ...           ...
# 1615                  0.4746      0.238462
# 1616                  0.6554      0.323077
# 1617                  0.5375      0.292308
# 1618                  0.4447      0.176923
# 1619                  0.4088      0.253846
#
# [1620 rows x 36 columns]

# %%
merged_data.columns
# Out:
# Index(['team', 'opponent', 'date', 'season', 'round', 'venue', 'gf', 'ga',
#        'h_form_gf', 'h_form_ga', 'h_form_xg', 'h_form_xga',
#        'h_form_standard sot', 'h_form_kp', 'h_form_xa', 'h_form_poss_x',
#        'h_form_touches att pen', 'h_form_carries prgdist',
#        'h_form_progressive passing dist', 'h_form_tackles tklw',
#        'h_form_challenges tkl%', 'h_form_saves', 'a_form_gf', 'a_form_ga',
#        'a_form_xg', 'a_form_xga', 'a_form_standard sot', 'a_form_kp',
#        'a_form_xa', 'a_form_poss_x', 'a_form_touches att pen',
#        'a_form_carries prgdist', 'a_form_progressive passing dist',
#        'a_form_tackles tklw', 'a_form_challenges tkl%', 'a_form_saves'],
#       dtype='object')

# %%
filtered_data = merged_data[
    ((merged_data['team'] == 'FUL') | (merged_data['opponent'] == 'FUL'))
].sort_values('date')
filtered_data[['team', 'opponent', 'date', 'gf', 'ga', 'h_form_gf', 'a_form_gf', 'h_form_ga', 'a_form_ga']]
# Out:
#      team opponent       date   gf   ga  h_form_gf  a_form_gf  h_form_ga  \
# 648   FUL      ARS 2020-09-12  0.0  3.0   0.000000   0.333333   0.333333
# 715   LEE      FUL 2020-09-19  4.0  3.0   0.444444   0.333333   0.333333
# 649   FUL      AVL 2020-09-28  0.0  3.0   0.000000   0.333333   0.333333
# 1540  WOL      FUL 2020-10-04  1.0  0.0   0.111111   0.000000   0.000000
# 1241  SHU      FUL 2020-10-18  1.0  1.0   0.044444   0.066667   0.166667
# ...   ...      ...        ...  ...  ...        ...        ...        ...
# 1236  NFO      FUL 2024-09-28  0.0  1.0   0.155556   0.211111   0.111111
# 1013  MCI      FUL 2024-10-05  3.0  2.0   0.188889   0.177778   0.144444
# 708   FUL      AVL 2024-10-19  1.0  3.0   0.200000   0.166667   0.166667
# 647   EVE      FUL 2024-10-26  1.0  1.0   0.144444   0.166667   0.033333
# 709   FUL      BRE 2024-11-04  2.0  1.0   0.133333   0.333333   0.211111
#
#       a_form_ga
# 648    0.000000
# 715    0.444444
# 649    0.000000
# 1540   0.111111
# 1241   0.266667
# ...         ...
# 1236   0.111111
# 1013   0.066667
# 708    0.111111
# 647    0.244444
# 709    0.277778
#
# [124 rows x 9 columns]

# %%
merged_data.columns
# Out:
# Index(['team', 'opponent', 'date', 'season', 'round', 'venue', 'gf', 'ga',
#        'h_form_gf', 'h_form_ga', 'h_form_xg', 'h_form_xga',
#        'h_form_standard sot', 'h_form_kp', 'h_form_xa', 'h_form_poss_x',
#        'h_form_touches att pen', 'h_form_carries prgdist',
#        'h_form_progressive passing dist', 'h_form_tackles tklw',
#        'h_form_challenges tkl%', 'h_form_saves', 'a_form_gf', 'a_form_ga',
#        'a_form_xg', 'a_form_xga', 'a_form_standard sot', 'a_form_kp',
#        'a_form_xa', 'a_form_poss_x', 'a_form_touches att pen',
#        'a_form_carries prgdist', 'a_form_progressive passing dist',
#        'a_form_tackles tklw', 'a_form_challenges tkl%', 'a_form_saves'],
#       dtype='object')

# %%
merged_data = pd.merge(merged_data, fb_data, left_on=['date', 'team'], right_on=['date', 'hometeam'], how='inner')
merged_data
# Out:
#      team opponent       date     season  round venue   gf   ga  h_form_gf  \
# 0     ARS      WHU 2020-09-19  2020-2021      2  Home  2.0  1.0   0.222222
# 1     ARS      SHU 2020-10-04  2020-2021      4  Home  2.0  1.0   0.222222
# 2     ARS      LEI 2020-10-25  2020-2021      6  Home  0.0  1.0   0.111111
# 3     ARS      AVL 2020-11-08  2020-2021      8  Home  0.0  3.0   0.066667
# 4     ARS      WOL 2020-11-29  2020-2021     10  Home  1.0  2.0   0.022222
# ...   ...      ...        ...        ...    ...   ...  ...  ...        ...
# 1615  WOL      CHE 2024-08-25  2024-2025      2  Home  2.0  6.0   0.033333
# 1616  WOL      NEW 2024-09-15  2024-2025      4  Home  1.0  2.0   0.111111
# 1617  WOL      LIV 2024-09-28  2024-2025      6  Home  1.0  2.0   0.122222
# 1618  WOL      MCI 2024-10-20  2024-2025      8  Home  1.0  2.0   0.200000
# 1619  WOL      CRY 2024-11-02  2024-2025     10  Home  2.0  2.0   0.200000
#
#       h_form_ga  ...  a_form_progressive passing dist  a_form_tackles tklw  \
# 0      0.111111  ...                         0.307441             0.185185
# 1      0.111111  ...                         0.192968             0.148148
# 2      0.155556  ...                         0.413355             0.296296
# 3      0.066667  ...                         0.359444             0.251852
# 4      0.111111  ...                         0.420660             0.355556
# ...         ...  ...                              ...                  ...
# 1615   0.277778  ...                         0.538757             0.451852
# 1616   0.311111  ...                         0.301145             0.392593
# 1617   0.288889  ...                         0.603053             0.459259
# 1618   0.377778  ...                         0.424203             0.281481
# 1619   0.288889  ...                         0.326083             0.544444
#
#       a_form_challenges tkl%  a_form_saves  hometeam  awayteam     b365h  \
# 0                     0.3330      0.076923       ARS       WHU  0.026198
# 1                     0.3330      0.230769       ARS       SHU  0.028428
# 2                     0.4307      0.230769       ARS       LEI  0.046823
# 3                     0.4148      0.261538       ARS       AVL  0.032887
# 4                     0.4561      0.092308       ARS       WOL  0.055184
# ...                      ...           ...       ...       ...       ...
# 1615                  0.4746      0.238462       WOL       CHE  0.182274
# 1616                  0.6554      0.323077       WOL       NEW  0.130435
# 1617                  0.5375      0.292308       WOL       LIV  0.386845
# 1618                  0.4447      0.176923       WOL       MCI  0.386845
# 1619                  0.4088      0.253846       WOL       CRY  0.080268
#
#          b365d     b365a  ftr
# 0     0.166667  0.156497    H
# 1     0.117647  0.174444    H
# 2     0.093137  0.095477    A
# 3     0.127451  0.138550    A
# 4     0.058824  0.093683    A
# ...        ...       ...  ...
# 1615  0.117647  0.021895    A
# 1616  0.068627  0.034458    A
# 1617  0.289216  0.006820    A
# 1618  0.313725  0.006820    A
# 1619  0.058824  0.062455    D
#
# [1620 rows x 42 columns]

# %%
merged_data.drop(columns=['hometeam', 'awayteam', 'venue'], inplace=True)
merged_data.rename(columns={'team': 'hometeam', 'opponent': 'awayteam'}, inplace=True)
merged_data
# Out:
#      hometeam awayteam       date     season  round   gf   ga  h_form_gf  \
# 0         ARS      WHU 2020-09-19  2020-2021      2  2.0  1.0   0.222222
# 1         ARS      SHU 2020-10-04  2020-2021      4  2.0  1.0   0.222222
# 2         ARS      LEI 2020-10-25  2020-2021      6  0.0  1.0   0.111111
# 3         ARS      AVL 2020-11-08  2020-2021      8  0.0  3.0   0.066667
# 4         ARS      WOL 2020-11-29  2020-2021     10  1.0  2.0   0.022222
# ...       ...      ...        ...        ...    ...  ...  ...        ...
# 1615      WOL      CHE 2024-08-25  2024-2025      2  2.0  6.0   0.033333
# 1616      WOL      NEW 2024-09-15  2024-2025      4  1.0  2.0   0.111111
# 1617      WOL      LIV 2024-09-28  2024-2025      6  1.0  2.0   0.122222
# 1618      WOL      MCI 2024-10-20  2024-2025      8  1.0  2.0   0.200000
# 1619      WOL      CRY 2024-11-02  2024-2025     10  2.0  2.0   0.200000
#
#       h_form_ga  h_form_xg  ...  a_form_touches att pen  \
# 0      0.111111   0.157143  ...                0.200000
# 1      0.111111   0.085714  ...                0.157895
# 2      0.155556   0.130000  ...                0.215789
# 3      0.066667   0.121429  ...                0.314737
# 4      0.111111   0.154286  ...                0.257895
# ...         ...        ...  ...                     ...
# 1615   0.277778   0.100000  ...                0.283158
# 1616   0.311111   0.142857  ...                0.208421
# 1617   0.288889   0.127143  ...                0.312632
# 1618   0.377778   0.114286  ...                0.449474
# 1619   0.288889   0.145714  ...                0.206316
#
#       a_form_carries prgdist  a_form_progressive passing dist  \
# 0                   0.293283                         0.307441
# 1                   0.231315                         0.192968
# 2                   0.362252                         0.413355
# 3                   0.254210                         0.359444
# 4                   0.357616                         0.420660
# ...                      ...                              ...
# 1615                0.347635                         0.538757
# 1616                0.201703                         0.301145
# 1617                0.465374                         0.603053
# 1618                0.630842                         0.424203
# 1619                0.217219                         0.326083
#
#       a_form_tackles tklw  a_form_challenges tkl%  a_form_saves     b365h  \
# 0                0.185185                  0.3330      0.076923  0.026198
# 1                0.148148                  0.3330      0.230769  0.028428
# 2                0.296296                  0.4307      0.230769  0.046823
# 3                0.251852                  0.4148      0.261538  0.032887
# 4                0.355556                  0.4561      0.092308  0.055184
# ...                   ...                     ...           ...       ...
# 1615             0.451852                  0.4746      0.238462  0.182274
# 1616             0.392593                  0.6554      0.323077  0.130435
# 1617             0.459259                  0.5375      0.292308  0.386845
# 1618             0.281481                  0.4447      0.176923  0.386845
# 1619             0.544444                  0.4088      0.253846  0.080268
#
#          b365d     b365a  ftr
# 0     0.166667  0.156497    H
# 1     0.117647  0.174444    H
# 2     0.093137  0.095477    A
# 3     0.127451  0.138550    A
# 4     0.058824  0.093683    A
# ...        ...       ...  ...
# 1615  0.117647  0.021895    A
# 1616  0.068627  0.034458    A
# 1617  0.289216  0.006820    A
# 1618  0.313725  0.006820    A
# 1619  0.058824  0.062455    D
#
# [1620 rows x 39 columns]

# %%
# #calculate point per game of each team to encode team_name
# points = {}
# games = {}
# for index, row in merged_data.iterrows():
#     hometeam = row['hometeam']
#     awayteam = row['awayteam']
#     if hometeam not in points:
#         points[hometeam] = 0
#         games[hometeam] = 0
#     if awayteam not in points:
#         points[awayteam] = 0
#         games[awayteam] = 0
#     games[hometeam] += 1
#     games[awayteam] += 1
#     if row['ftr'] == 'H':
#         points[hometeam] += 3
#     elif row['ftr'] == 'A':
#         points[awayteam] += 3
#     else:
#         points[hometeam] += 1
#         points[awayteam] += 1

# %%
# ppg = {team: points[team] / games[team] for team in points}
# # sort teams by ppg
# sorted_teams = sorted(ppg, key=ppg.get, reverse=True)
# team_map = {team: i for i, team in enumerate(sorted_teams)}
# team_map

# %%
# import json
# with open('../../data/team_map.json', 'w') as f:
#     json.dump(team_map, f)

# %%
# merged_data['hometeam'] = merged_data['hometeam'].map(team_map)
# merged_data['awayteam'] = merged_data['awayteam'].map(team_map)
# merged_data

# %%
merged_data.rename(columns={'ftr': 'result'}, inplace=True)
# use one hot encoding for result
merged_data = pd.get_dummies(merged_data, columns=['result'])
merged_data
# Out:
#      hometeam awayteam       date     season  round   gf   ga  h_form_gf  \
# 0         ARS      WHU 2020-09-19  2020-2021      2  2.0  1.0   0.222222
# 1         ARS      SHU 2020-10-04  2020-2021      4  2.0  1.0   0.222222
# 2         ARS      LEI 2020-10-25  2020-2021      6  0.0  1.0   0.111111
# 3         ARS      AVL 2020-11-08  2020-2021      8  0.0  3.0   0.066667
# 4         ARS      WOL 2020-11-29  2020-2021     10  1.0  2.0   0.022222
# ...       ...      ...        ...        ...    ...  ...  ...        ...
# 1615      WOL      CHE 2024-08-25  2024-2025      2  2.0  6.0   0.033333
# 1616      WOL      NEW 2024-09-15  2024-2025      4  1.0  2.0   0.111111
# 1617      WOL      LIV 2024-09-28  2024-2025      6  1.0  2.0   0.122222
# 1618      WOL      MCI 2024-10-20  2024-2025      8  1.0  2.0   0.200000
# 1619      WOL      CRY 2024-11-02  2024-2025     10  2.0  2.0   0.200000
#
#       h_form_ga  h_form_xg  ...  a_form_progressive passing dist  \
# 0      0.111111   0.157143  ...                         0.307441
# 1      0.111111   0.085714  ...                         0.192968
# 2      0.155556   0.130000  ...                         0.413355
# 3      0.066667   0.121429  ...                         0.359444
# 4      0.111111   0.154286  ...                         0.420660
# ...         ...        ...  ...                              ...
# 1615   0.277778   0.100000  ...                         0.538757
# 1616   0.311111   0.142857  ...                         0.301145
# 1617   0.288889   0.127143  ...                         0.603053
# 1618   0.377778   0.114286  ...                         0.424203
# 1619   0.288889   0.145714  ...                         0.326083
#
#       a_form_tackles tklw  a_form_challenges tkl%  a_form_saves     b365h  \
# 0                0.185185                  0.3330      0.076923  0.026198
# 1                0.148148                  0.3330      0.230769  0.028428
# 2                0.296296                  0.4307      0.230769  0.046823
# 3                0.251852                  0.4148      0.261538  0.032887
# 4                0.355556                  0.4561      0.092308  0.055184
# ...                   ...                     ...           ...       ...
# 1615             0.451852                  0.4746      0.238462  0.182274
# 1616             0.392593                  0.6554      0.323077  0.130435
# 1617             0.459259                  0.5375      0.292308  0.386845
# 1618             0.281481                  0.4447      0.176923  0.386845
# 1619             0.544444                  0.4088      0.253846  0.080268
#
#          b365d     b365a  result_A  result_D  result_H
# 0     0.166667  0.156497     False     False      True
# 1     0.117647  0.174444     False     False      True
# 2     0.093137  0.095477      True     False     False
# 3     0.127451  0.138550      True     False     False
# 4     0.058824  0.093683      True     False     False
# ...        ...       ...       ...       ...       ...
# 1615  0.117647  0.021895      True     False     False
# 1616  0.068627  0.034458      True     False     False
# 1617  0.289216  0.006820      True     False     False
# 1618  0.313725  0.006820      True     False     False
# 1619  0.058824  0.062455     False      True     False
#
# [1620 rows x 41 columns]

# %%
merged_data.to_csv('../../data/raw/fbdata_fbref.csv', index=False)
