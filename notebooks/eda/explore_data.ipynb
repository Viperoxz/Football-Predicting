# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/fbdata_fbref.csv')
df.head()
# Out:
#   hometeam awayteam        date     season  round   gf   ga  h_form_gf  \
# 0      ARS      WHU  2020-09-19  2020-2021      2  2.0  1.0   0.222222
# 1      ARS      SHU  2020-10-04  2020-2021      4  2.0  1.0   0.222222
# 2      ARS      LEI  2020-10-25  2020-2021      6  0.0  1.0   0.111111
# 3      ARS      AVL  2020-11-08  2020-2021      8  0.0  3.0   0.066667
# 4      ARS      WOL  2020-11-29  2020-2021     10  1.0  2.0   0.022222
#
#    h_form_ga  h_form_xg  ...  a_form_progressive passing dist  \
# 0   0.111111   0.157143  ...                         0.307441
# 1   0.111111   0.085714  ...                         0.192968
# 2   0.155556   0.130000  ...                         0.413355
# 3   0.066667   0.121429  ...                         0.359444
# 4   0.111111   0.154286  ...                         0.420660
#
#    a_form_tackles tklw  a_form_challenges tkl%  a_form_saves     b365h  \
# 0             0.185185                  0.3330      0.076923  0.026198
# ...

# %%
df.columns
# Out:
# Index(['hometeam', 'awayteam', 'date', 'season', 'round', 'gf', 'ga',
#        'h_form_gf', 'h_form_ga', 'h_form_xg', 'h_form_xga',
#        'h_form_standard sot', 'h_form_kp', 'h_form_xa', 'h_form_poss_x',
#        'h_form_touches att pen', 'h_form_carries prgdist',
#        'h_form_progressive passing dist', 'h_form_tackles tklw',
#        'h_form_challenges tkl%', 'h_form_saves', 'a_form_gf', 'a_form_ga',
#        'a_form_xg', 'a_form_xga', 'a_form_standard sot', 'a_form_kp',
#        'a_form_xa', 'a_form_poss_x', 'a_form_touches att pen',
#        'a_form_carries prgdist', 'a_form_progressive passing dist',
#        'a_form_tackles tklw', 'a_form_challenges tkl%', 'a_form_saves',
#        'b365h', 'b365d', 'b365a', 'result_A', 'result_D', 'result_H'],
#       dtype='object')

# %%
df.dtypes
# Out:
# hometeam                            object
# awayteam                            object
# date                                object
# season                              object
# round                                int64
# gf                                 float64
# ga                                 float64
# h_form_gf                          float64
# h_form_ga                          float64
# h_form_xg                          float64
# h_form_xga                         float64
# h_form_standard sot                float64
# h_form_kp                          float64
# h_form_xa                          float64
# h_form_poss_x                      float64
# h_form_touches att pen             float64
# h_form_carries prgdist             float64
# h_form_progressive passing dist    float64
# h_form_tackles tklw                float64
# h_form_challenges tkl%             float64
# h_form_saves                       float64
# a_form_gf                          float64
# ...

# %%
df['formation'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\admin\anaconda3\envs\ai_learning\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'formation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['formation'].value_counts()
#
# ...
