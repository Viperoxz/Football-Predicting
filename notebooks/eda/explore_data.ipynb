# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/fbdata_fbref.csv')
df.head()
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 1  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 2  2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# 3  2024-10-20  16:30  Premier League   Matchweek 8  Sun  Home      W  2.0
# 4  2024-11-02  15:00  Premier League  Matchweek 10  Sat  Home      W  2.0
#
#     ga                  opponent  ...  aerial duels lost     season  \
# 0  0.0                 Brentford  ...                8.0  2024-2025
# 1  1.0         Nottingham Forest  ...               12.0  2024-2025
# 2  0.0               Bournemouth  ...                6.0  2024-2025
# 3  1.0                   Chelsea  ...               10.0  2024-2025
# 4  1.0  Brighton and Hove Albion  ...                8.0  2024-2025
#
#         team   hometeam                  awayteam b365h b365d b365a over2.5  \
# ...

# %%
df.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent',
#        ...
#        'aerial duels lost', 'season', 'team', 'hometeam', 'awayteam', 'b365h',
#        'b365d', 'b365a', 'over2.5', 'under2.5'],
#       dtype='object', length=142)

# %%
df.dtypes
# Out:
# date         object
# time         object
# comp         object
# round        object
# day          object
#              ...
# b365h       float64
# b365d       float64
# b365a       float64
# over2.5     float64
# under2.5    float64
# Length: 142, dtype: object

# %%
df['formation'].value_counts()
# Out:
# formation
# 4-2-3-1       1541
# 4-3-3         1135
# 4-4-2          647
# 3-4-3          631
# 4-4-1-1        301
# 3-5-2          279
# 4-1-4-1        262
# 5-4-1          130
# 5-3-2          104
# 3-4-1-2         91
# 4-5-1           80
# 4-2-2-2         65
# 4-1-2-1-2◆      54
# 3-5-1-1         51
# 4-3-1-2         49
# 3-1-4-2         30
# 4-3-2-1         28
# 3-2-4-1         24
# 3-3-3-1         12
# 4-2-4-0          2
# 3-4-3◆           2
# 4-1-3-2          2
# Name: count, dtype: int64
