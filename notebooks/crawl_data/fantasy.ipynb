# %%
import pandas as pd

# %%
fts_21 = pd.read_csv('../../data/raw/fantasy/21.csv')
fts_22 = pd.read_csv('../../data/raw/fantasy/22.csv')
fts_23 = pd.read_csv('../../data/raw/fantasy/23.csv')
fts_24 = pd.read_csv('../../data/raw/fantasy/24.csv')
fts_25 = pd.read_csv('../../data/raw/fantasy/25.csv')
fts_25 = fts_25[fts_25['GW'] <= 10]

# %%
team_encode = pd.read_csv('../../data/raw/fantasy/team_encode.csv')
team_encode = team_encode[team_encode['season'].isin(['2019-20' ,'2020-21', '2021-22', '2022-23', '2023-24'])]

# %%
# team_map_25 = {
#     1: 'Arsenal',
#     2: 'Aston Villa',
#     3: 'Bournemouth',
#     4: 'Brentford',
#     5: 'Brighton',
#     6: 'Chelsea',
#     7: 'Crystal Palace',
#     8: 'Everton',
#     9: 'Fulham',
#     10: 'Ipswich',
#     11: 'Leicester',
#     12: 'Liverpool',
#     13: 'Man City',
#     14: 'Man Utd',
#     15: 'Newcastle',
#     16: "Nott'm Forest",
#     17: 'Southampton',
#     18: 'Spurs',
#     19: 'West Ham',
#     20: 'Wolves'
# }

# #append [2024-25, team, team_name] to team_encode
# team_encode_25 = pd.DataFrame(team_map_25.items(), columns=['team', 'team_name'])
# team_encode_25['season'] = '2024-25'
# team_encode = pd.concat([team_encode, team_encode_25])
# team_encode

# %%
# def create_opp_names(df, season):
#     opp_team_names = df['opponent_team'].apply(
#         lambda x: team_encode[(team_encode['team'] == x) & (team_encode['season'] == season)]['team_name'].values[0]
#         if not team_encode[(team_encode['team'] == x) & (team_encode['season'] == season)].empty
#         else None
#     )
#     df['opponent_team_name'] = opp_team_names
#     return df

# %%
# fts_21 = create_opp_names(fts_21, '2020-21')
# fts_22 = create_opp_names(fts_22, '2021-22')
# fts_23 = create_opp_names(fts_23, '2022-23')
# fts_24 = create_opp_names(fts_24, '2023-24')
# fts_25 = create_opp_names(fts_25, '2024-25')

# %%
fts_21['season'] = '2020-2021'
fts_22['season'] = '2021-2022'
fts_23['season'] = '2022-2023'
fts_24['season'] = '2023-2024'
fts_25['season'] = '2024-2025'

# %%
fts_21.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'round', 'saves', 'selected', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'GW', 'season'],
#       dtype='object')

# %%
"""
features for layer 2:
    total_points, bonus, value, creativity, influence, threat, selected, transfers_balance

create "time_played": 1 if "minutes" > 45 else 0

create 4 df: home_1, away_1, home_0, away_0
"""
# Out:
# '\nfeatures for layer 2:\n    total_points, bonus, value, creativity, influence, threat, selected, transfers_balance\n\ncreate "time_played": 1 if "minutes" > 45 else 0\n\ncreate 4 df: home_1, away_1, home_0, away_0\n'

# %%
fts_21 = fts_21[['name', 'team', 'GW', 'season', 'total_points', 'bonus', 'value', 'creativity', 'influence', 'threat', 'selected', 'transfers_balance', 
                 'minutes', 'kickoff_time', 'was_home']]
fts_22 = fts_22[['name', 'team', 'GW', 'season', 'total_points', 'bonus', 'value', 'creativity', 'influence', 'threat', 'selected', 'transfers_balance', 
                 'minutes', 'kickoff_time', 'was_home']]
fts_23 = fts_23[['name', 'team', 'GW', 'season', 'total_points', 'bonus', 'value', 'creativity', 'influence', 'threat', 'selected', 'transfers_balance', 
                 'minutes', 'kickoff_time', 'was_home']]
fts_24 = fts_24[['name', 'team', 'GW', 'season', 'total_points', 'bonus', 'value', 'creativity', 'influence', 'threat', 'selected', 'transfers_balance', 
                 'minutes', 'kickoff_time', 'was_home']]
fts_25 = fts_25[['name', 'team', 'GW', 'season', 'total_points', 'bonus', 'value', 'creativity', 'influence', 'threat', 'selected', 'transfers_balance', 
                 'minutes', 'kickoff_time', 'was_home']]

# %%
fts = pd.concat([fts_21, fts_22, fts_23, fts_24, fts_25])
fts.head()
# Out:
#                  name           team  GW     season  total_points  bonus  \
# 0      Aaron Connolly       Brighton   1  2020-2021             1      0
# 1     Aaron Cresswell       West Ham   1  2020-2021             1      0
# 2          Aaron Mooy       Brighton   1  2020-2021             0      0
# 3      Aaron Ramsdale  Sheffield Utd   1  2020-2021             1      0
# 4  Abdoulaye Doucouré        Everton   1  2020-2021             3      0
#
#    value  creativity  influence  threat  selected  transfers_balance  minutes  \
# 0     55         0.3        1.2    32.0     32205                  0       45
# 1     50        11.2       10.4     0.0     70232                  0       90
# 2     50         0.0        0.0     0.0      2010                  0        0
# 3     50         0.0       18.2     0.0    462939                  0       90
# 4     55        44.6       20.4     4.0    143040                  0       90
#
#            kickoff_time  was_home
# ...

# %%
len(fts)
# Out:
# 112594

# %%
fts.isnull().sum()
# Out:
# name                 0
# team                 0
# GW                   0
# season               0
# total_points         0
# bonus                0
# value                0
# creativity           0
# influence            0
# threat               0
# selected             0
# transfers_balance    0
# minutes              0
# kickoff_time         0
# was_home             0
# dtype: int64

# %%
name_map = {
    'adama traore diarra': 'adama traore',
    'ademipo odubeko': 'mipo odubeko',
    'adrian san miguel del castillo': 'adrian',
    'ahmed el mohamady': 'ahmed elmohamady',
    'ahmed el-sayed hegazy': 'ahmed hegazy',
    'ajibola alese': 'aji alese',
    'albert sambi lokonga': 'albert lokonga',
    'alejandro garnacho ferreyra': 'alejandro garnacho',
    'alex mighten': 'Alexander Mighten',
    'alex moreno lopera': 'alex moreno',
    'alex nicolao telles': 'Alex Telles',
    'alexandre moreno lopera': 'alex moreno',
    'ali al-hamadi': 'Ali Al Hamadi',
    'alisson ramses becker': 'Alisson Becker',
    'allan marques loureiro': 'allan',
    'alvaro fernandez carreras': 'Álvaro Fernández',
    'andre filipe tavares gomes': 'André Gomes',
    'andre tavares gomes': 'André Gomes',
    'andre trindade da costa neto': 'André',
    'andre-frank zambo anguissa': 'Frank Anguissa',
    'andreas hoelgebaum pereira': 'Andreas Pereira',
    'andrew robertson': 'Andy Robertson',
    'andrey nascimento dos santos': 'Andrey Santos',
    'andriy yarmolenko': 'Andrey Yarmolenko',
    'anis slimane': 'Anis Ben Slimane',
    'anssumane fati vieira': 'Ansu Fati',
    'antony matheus dos santos': 'antony',
    'arijanet muric': 'Aro Murić',
    'arnaut danjuma groeneveld': 'Arnaut Danjuma',
    'arthur henrique ramos de oliveira melo': 'Arthur Melo',
    'ayotomiwa dele-bashiru': 'Tom Dele-Bashiru',
    'bamidele alli': 'dele alli',
    'ben brereton diaz': 'Ben Brereton',
    'benicio baker-boaitey': 'Benicio Boaitey',
    'benjamin chilwell': 'Ben Chilwell',
    'benjamin chrisene': 'Ben Chrisene',
    'benjamin white': 'Ben White',
    'bernard anicio caldeira duarte': 'Bernard',
    'bernardo fernandes da silva junior': 'Bernardo',
    'bernardo mota veiga de carvalho e silva': 'Bernardo Silva',
    'bernardo veiga de carvalho e silva': 'Bernardo Silva',
    'bobby decordova-reid': 'Bobby De Cordova-Reid',
    'boubacar traore': 'Boubacar Traoré II',
    'brandon aguilera zamora': 'Brandon Aguilera',
    'brandon pierrick': 'Brandon Pierrick',
    'bruno andre cavaco jordao': 'Bruno Jordão',
    'bruno guimaraes rodriguez moura': 'Bruno Guimarães',
    'bruno miguel borges fernandes': 'Bruno Fernandes',
    'bryan gil salvatierra': 'Bryan Gil',
    'callum scanlon': 'Calum Scanlon',
    'carlos alcaraz duran': 'Carlos Alcaraz',
    'carlos henrique casimiro': 'Casemiro',
    'carlos miguel dos santos pereira': 'Carlos Miguel',
    'carlos roberto forbs borges': 'Carlos Forbs',
    'carlos vinicius alves morais': 'Carlos Vinícius',
    'cedric alves soares': 'Cédric',
    'cedric soares': 'Cédric',
    'cesar azpilicueta': 'Azpilicueta',
    'chadi riad dnanou': 'Chadi Riad',
    'christian atsu': 'Christian Atsu',
    'claudio bravo': 'Claudio Bravo',
    'conrad egan-riley': 'CJ Egan-Riley',
    'cristiano ronaldo dos santos aveiro': 'Cristiano Ronaldo',
    'daniel castelo podence': 'Daniel Podence',
    'daniel ceballos fernandez': 'Dani Ceballos',
    'daniel james': 'Dan James',
    "daniel n'lundulu": "Dan N'Lundulu",
    'danilo dos santos de oliveira': 'Danilo',
    'darwin nunez ribeiro': 'Darwin Núñez',
    'david datro fofana': 'David Fofana',
    'david de gea': 'De Gea',
    'david de gea quintana': 'De Gea',
    'david luiz moreira marinho': 'David Luiz',
    'david raya martin': 'David Raya',
    'deivid washington de souza eugenio': 'Deivid Washington',
    'detlef esapa osong': 'Detlef Osong',
    'diego carlos santos silva': 'Diego Carlos',
    'diego da silva costa': 'Diego Costa',
    'diego llorente': 'Llorente',
    'diego manuel jadon da silva moreira': 'Diego Moreira',
    'diogo dalot teixeira': 'Diogo Dalot',
    'diogo pinheiro monteiro': 'Diogo Monteiro',
    'diogo teixeira da silva': 'Diogo Jota',
    'djordje petrovic': 'Đorđe Petrović',
    'domingos quina': 'Domingos Quina',
    'dominic ballard': 'Dom Ballard',
    'dominic dos santos martins': 'Dominic Martins',
    'dominic solanke-mitchell': 'Dominic Solanke',
    'douglas luiz soares de paulo': 'Douglas Luiz',
    'ederson santana de moraes': 'Ederson',
    'edson alvarez velazquez': 'Edson Álvarez',
    'edward nketiah': 'Eddie Nketiah',
    'elliot thorpe': 'Harvey Elliott',
    'emerson aparecido leite de souza junior': 'Emerson Royal',
    'emerson leite de souza junior': 'Emerson Royal',
    'emerson palmieri dos santos': 'Emerson',
    'emiliano buendia stati': 'Emiliano Buendia',
    'emiliano martinez romero': 'Emiliano Martínez',
    'endo wataru': 'Wataru Endō',
    'ezri konsa ngoyo': 'Ezri Konsa',
    'fabio ferreira vieira': 'Fábio Vieira',
    'fabio freitas gouveia carvalho': 'Fabio Carvalho',
    'fabio henrique tavares': 'Fabinho',
    'fabricio agosto ramirez': 'Fabricio',
    'facundo pellistri rebollo': 'Facundo Pellistri',
    'faustino anjorin': 'Tino Anjorin',
    'felipe anderson pereira gomes': 'Felipe Anderson',
    'felipe augusto de almeida monteiro': 'Felipe Monteiro',
    'felipe rodrigues da silva': 'Morato',
    'fernando luiz rosa': 'Fernandinho',
    'fernando marcal': 'Marçal',
    'filip benkovic': 'Filip Benković',
    'filip marschall': 'Filip Marshall',
    'fin stevens': 'Finley Stevens',
    'florian lejeune': 'Florian Lejeune',
    'francisco casilla cortes': 'Kiko Casilla',
    'francisco evanilson de lima barbosa': 'Evanilson',
    'francisco femenia far': 'Kiko Femenía',
    'francisco jorge tomas oliveira': 'Chiquinho',
    'francisco machado mota de castro trincao': 'Trincão',
    'franco umeh-chibueze': 'Franco Umeh',
    'frederico rodrigues de paula santos': 'Fred',
    'frederik alves': 'Frederik Alves Ibsen',
    'gabriel dos santos magalhaes': 'Gabriel Magalhães',
    'gabriel fernando de jesus': 'Gabriel Jesus',
    'gabriel martinelli silva': 'Gabriel Martinelli',
    'gabriel teodoro martinelli silva': 'Gabriel Martinelli',
    'gedson carvalho fernandes': 'Gedson Fernandes',
    'giovanni reyna': 'Gio Reyna',
    'glenn murray': 'Glenn Murray',
    'goncalo manuel ganchinho guedes': 'Gonçalo Guedes',
    'gustavo henrique furtado scarpa': 'Gustavo Scarpa',
    'hector junior firpo adames': 'Junior Firpo',
    'helder wander sousa de azevedo e costa': 'Hélder Costa',
    'henri lansbury': 'Henri Lansbury',
    'hugo bueno lopez': 'Hugo Bueno',
    'hwang hee-chan': 'Hee-chan Hwang',
    'hwang ui-jo': 'Ui-jo Hwang',
    'ian carlo poveda-ocampo': 'Ian Poveda',
    'igor julio dos santos de paulo': 'Igor',
    'illia zabarnyi': 'Ilya Zabarnyi',
    'indiana vassilev': 'Indiana Vassilev',
    'isaac success ajayi': 'Isaac Success',
    'ivan neves abreu cavaleiro': 'Ivan Cavaleiro',
    'ivan ricardo neves abreu cavaleiro': 'Ivan Cavaleiro',
    'jack wilshere': 'Jack Wilshere',
    'jaden philogene-bidace': 'Jaden Philogene',
    'javier manquillo': 'Manquillo',
    'javier manquillo gaitan': 'Manquillo',
    'jean-ricner bellegarde': 'Jean Bellegarde',
    'jefferson lerma solis': 'Jefferson Lerma',
    'jens cajuste': 'Jens-Lys Cajuste',
    'jeremy sarmiento morante': 'Jeremy Sarmiento',
    'joao cavaco cancelo': 'João Cancelo',
    'joao felix sequeira': 'João Félix',
    'joao filipe iria santos moutinho': 'João Moutinho',
    'joao neves virginia': 'João Virgínia',
    'joao palhinha goncalves': 'João Palhinha',
    'joao pedro cavaco cancelo': 'João Cancelo',
    'joao pedro ferreira silva': 'Jota Silva',
    'joao pedro junqueira de jesus': 'João Pedro',
    'joao victor gomes da silva': 'João Gomes',
    'joe ayodele-aribo': 'Joe Aribo',
    'joelinton cassio apolinario de lira': 'Joelinton',
    'johann berg gudmundsson': 'Jóhann Guðmundsson',
    'jonathan castro otto': 'Jonny',
    'jorge cuenca barreno': 'Jorge Cuenca',
    'jorge luiz frello filho': 'Jorginho',
    'jose diogo dalot teixeira': 'Diogo Dalot',
    'jose ignacio peleteiro romallo': 'Jota Peleteiro',
    'jose malheiro de sa': 'José Sá',
    'joseph gomez': 'Joe Gomez',
    'joseph hodge': 'Joe Hodge',
    'joseph mcglynn': 'Joe McGlynn',
    'joseph whitworth': 'Joe Whitworth',
    'joseph willock': 'Joe Willock',
    'josh brooking': 'Joshua Brooking',
    'josh dasilva': 'Joshua Dasilva',
    'josh king': 'Joshua King',
    'josh martin': 'Josh Martin',
    'joshua sargent': 'Josh Sargent',
    'joshua wilson-esbrand': 'Josh Wilson-Esbrand',
    'juan camilo hernandez suarez': 'Cucho Hernández',
    'juan foyth': 'Juan Foyth',
    'juan larios lopez': 'Juan Larios',
    'julian araujo zuniga': 'Julián Araujo',
    'junior firpo adames': 'Junior Firpo',
    'kaine hayden': 'Kaine Kesler-Hayden',
    'kaine kesler hayden': 'Kaine Kesler-Hayden',
    'kayky da silva chagas': 'Kayky',
    'kell watts': 'Kell Watts',
    'kelland watts': 'Kell Watts',
    'kepa arrizabalaga': 'Kepa',
    'kim ji-soo': 'Ji-soo Kim',
    'konstantinos tsimikas': 'Kostas Tsimikas',
    'leo fuhr hjelde': 'Leo Hjelde',
    'leonardo campana': 'Leonardo Campana',
    'lino da cruz sousa': 'Lino Sousa',
    'lucas rodrigues moura da silva': 'Lucas Moura',
    'lucas tolentino coelho de lima': 'Lucas Paquetá',
    'lucas torreira': 'Lucas Torreira',
    'lucas torreira di pascua': 'Lucas Torreira',
    'luis guilherme lira dos santos': 'Luis Guilherme',
    'luis sinisterra lucumi': 'Luis Sinisterra',
    'luke mbete-tabu': 'Luke Mbete',
    'lyanco evangelista silveira neves vojnovic': 'Lyanco',
    'lyanco silveira neves vojnovic': 'Lyanco',
    'mads bech sorensen': 'Mads Bech',
    'mads juel andersen': 'Mads Andersen',
    'mads roerslev rasmussen': 'Mads Roerslev',
    'mahmoud ahmed ibrahim hassan': 'Trézéguet',
    'manuel benson hedilazio': 'Manuel Benson',
    'marc cucurella': 'Cucurella',
    'marc cucurella saseta': 'Cucurella',
    'marc guiu paz': 'Marc Guiu',
    'marc jurado gomez': 'Marc Jurado',
    'marc roca junque': 'Marc Roca',
    'marcelo de araujo pitaluga filho': 'Marcelo',
    'marcus myers-harness': 'Marcus Harness',
    'marcus oliveira alencar': 'Marquinhos Oliveira',
    'martin montoya': 'Martín Montoya',
    'mateo joseph fernandez': 'Mateo Joseph',
    'mateus cardoso lemos martins': 'Tetê',
    'mateus goncalo espanha fernandes': 'Mateus Fernandes',
    'matheus franca de oliveira': 'Matheus França',
    'matheus luiz nunes': 'Matheus Nunes',
    'matheus santos carneiro da cunha': 'Matheus Cunha',
    'mathias jorgensen': 'Zanka',
    'matt phillips': 'Matthew Phillips',
    'matteo guendouzi': 'Mattéo Guendouzi',
    'matthew cash': 'Matty Cash',
    'matthew smith': 'Matt Smith',
    'max kilman': 'Maximilian Kilman',
    'max kinsey': 'Maxwell Kinsey-Wellings',
    'max kinsey-wellings': 'Maxwell Kinsey-Wellings',
    'maximilian wober': 'Max Wöber',
    'maxwell haygarth': 'Max Haygarth',
    'mbwana ally samatta': 'Mbwana Samatta',
    'mbwana samatta': 'Mbwana Samatta',
    'mesut ozil': 'Mesut Özil',
    'michale olakigbe': 'Michael Olakigbe',
    'miguel almiron rejala': 'Miguel Almirón',
    'mitoma kaoru': 'Kaoru Mitoma',
    'mohamed naser el sayed elneny': 'Mohamed Elneny',
    'mohamed salah': 'Mo Salah',
    'moises caicedo corozo': 'Moisés Caicedo',
    'murillo santiago costa dos santos': 'Murillo',
    'mykhailo mudryk': 'Mykhaylo Mudryk',
    'nathan wood-gordon': 'Nathan Wood',
    'nelson cabral semedo': 'Nélson Semedo',
    'nicolas nkoulou': 'Nicolas N´Koulou',
    'norberto bercique gomes betuncal': 'Beto',
    'norberto murara neto': 'Neto',
    'nuno varela tavares': 'Nuno Tavares',
    'odeluga offiah': 'Odel Offiah',
    'odysseas vlachodimos': 'Odisseas Vlachodimos',
    'oghenekaro peter etebo': 'Peter Etebo',
    'oliver arblaster': 'Ollie Arblaster',
    'olu aina': 'Ola Aina',
    'oluwasemilogo adesewo ibidapo ajayi': 'Semi Ajayi',
    'omari giraud-hutchinson': 'Omari Hutchinson',
    'oriol romeu vidal': 'Oriol Romeu',
    'orjan nyland': 'Ørjan Nyland',
    'pablo fornals malla': 'Pablo Fornals',
    'pablo hernandez dominguez': 'Pablo Hernández',
    'pablo mari villar': 'Pablo Marí',
    'pape matar sarr': 'Pape Sarr',
    'pedro cardoso de lima': 'Pedro Lima',
    'pedro lomba neto': 'Pedro Neto',
    'pelenda joshua dasilva': 'Joshua Dasilva',
    'pelly ruddock mpanzu': 'Pelly-Ruddock Mpanzu',
    'philippe coutinho correia': 'Philippe Coutinho',
    'raphael dias belloli': 'Raphinha',
    'rayan ait-nouri': 'Rayan Aït Nouri',
    'rekeem harper': 'Rakeem Harper',
    'renan augusto lodi dos santos': 'Renan Lodi',
    'renato palma veiga': 'Renato Veiga',
    'ricardo barbosa pereira': 'Ricardo Pereira',
    'ricardo domingos barbosa pereira': 'Ricardo Pereira',
    'richarlison de andrade': 'Richarlison',
    'robert elliot': 'Rob Elliot',
    'robert kenedy nunes do nascimento': 'Kenedy',
    'robert street': 'Rob Street',
    'roberto jimenez gago': 'Roberto',
    "rodrigo 'rodri' hernandez": 'Rodri',
    'rodrigo duarte ribeiro': 'Rodrigo Ribeiro',
    'rodrigo hernandez': 'Rodri',
    'rodrigo martins gomes': 'Rodrigo Gomes',
    'rodrigo moreno': 'Rodrigo',
    'rodrigo muniz carvalho': 'Rodrigo Muniz',
    'romelu lukaku bolingoli': 'Romelu Lukaku',
    'ruben da silva neves': 'Rúben Neves',
    'ruben diogo da silva neves': 'Rúben Neves',
    'ruben gato alves dias': 'Rúben Dias',
    'ruben goncalo silva nascimento vinagre': 'Rúben Vinagre',
    'ruben nascimento vinagre': 'Rúben Vinagre',
    'ruben santos gato alves dias': 'Rúben Dias',
    'rui pedro dos santos patricio': 'Rui Patrício',
    'runar alex runarsson': 'Alex Rúnarsson',
    'sam szmodics': 'Sammie Szmodics',
    'samir caetano de souza santos': 'Samir De Souza',
    'samuel amo-ameyaw': 'Sam Amo-Ameyaw',
    "savio 'savinho' moreira de oliveira": 'Sávinho',
    'sergi canos tenes': 'Sergi Canós',
    'sergio reguilon': 'Reguilón',
    'sergio romero': 'Sergio Romero',
    'simon moore': 'Simon Moore',
    'sofiane boufal': 'Sofiane Boufal',
    'sokratis papastathopoulos': 'Sokratis Papastathopoulos',
    'solomon march': 'Solly March',
    'son heung-min': 'Heung-min Son',
    'stefan bajcetic maquieira': 'Stefan Bajčetić',
    'stefan ortega moreno': 'Stefan Ortega',
    'sugawara yukinari': 'Yukinari Sugawara',
    'tanguy ndombele alvaro': 'Tanguy Ndombèlé',
    'tariqe fosu-henry': 'Tariqe Fosu',
    'thakgalo leshabela': 'Khanya Leshabela',
    'thiago alcantara do nascimento': 'Thiago',
    'thiago emiliano da silva': 'Thiago Silva',
    'thiago thiago': 'Thiago Silva',
    'tom cannon': 'Thomas Cannon',
    'tom mcgill': 'Thomas McGill',
    'tomiyasu takehiro': 'Takehiro Tomiyasu',
    'toti antonio gomes': 'Toti',
    'treymaurice nyoni': 'Trey Nyoni',
    'troy parrott': 'Troy Parrott',
    'valentino livramento': 'Tino Livramento',
    'valintino adedokun': 'Valentin Adedokun',
    'vicente guaita': 'Guaita',
    'victor da silva': 'Vitinho',
    'vini de souza costa': 'Vinicius Souza',
    'vitalii mykolenko': 'Vitaliy Mykolenko',
    'vitor ferreira': 'Vitinha',
    'vontae daley-campbell': 'Vontae Campbell',
    'wanya marcal-madivadua': 'Wanya Marçal',
    'wesley moraes': 'Wesley',
    'wesley moraes ferreira da silva': 'Wesley',
    'will lankshear': 'William Lankshear',
    'william fish': 'Will Fish',
    'william smallbone': 'Will Smallbone',
    'willian borges da silva': 'Willian',
    'willian jose da silva': 'Willian José',
    'winston reid': 'Winston Reid',
    'xande nascimento da costa silva': 'Xande Silva',
    'yago de santiago alonso': 'Yago Santiago',
    'yegor yarmoliuk': 'Yegor Yarmolyuk',
    'yehor yarmoliuk': 'Yegor Yarmolyuk',
    'yerson mosquera valdelamar': 'Yerson Mosquera',
    'yoshinori muto': 'Yoshinori Mutō',
    'youssef ramalho chermiti': 'Youssef Chermiti',
    'yunus emre konak': 'Yunus Konak',
    'carlos ribeiro dias': 'cafu',
    'ben jackson': 'benjamin jackson',
    'aidan francis-clarke': 'aiden francis-clarke',
    'james storer': 'jimmy storer',
    'joel robles': 'joel',
    'kamari doyle': 'kami doyle'
}

# %%
from unidecode import unidecode

def normalize_name(name):
    return unidecode(name.strip().lower())

# %%
fts['name'] = fts['name'].apply(lambda x: normalize_name(x))
fts['name'] = fts['name'].apply(lambda x: normalize_name(name_map[x]) if x in name_map else x)
fts['name'].nunique()
# Out:
# 1636

# %%
def create_time_category(df):
    df['play_time_category'] = df['minutes'].apply(lambda x: 1 if x > 45 else 0)
    return df

# %%
fts = create_time_category(fts)
fts.head()
# Out:
#                  name           team  GW     season  total_points  bonus  \
# 0      aaron connolly       Brighton   1  2020-2021             1      0
# 1     aaron cresswell       West Ham   1  2020-2021             1      0
# 2          aaron mooy       Brighton   1  2020-2021             0      0
# 3      aaron ramsdale  Sheffield Utd   1  2020-2021             1      0
# 4  abdoulaye doucoure        Everton   1  2020-2021             3      0
#
#    value  creativity  influence  threat  selected  transfers_balance  minutes  \
# 0     55         0.3        1.2    32.0     32205                  0       45
# 1     50        11.2       10.4     0.0     70232                  0       90
# 2     50         0.0        0.0     0.0      2010                  0        0
# 3     50         0.0       18.2     0.0    462939                  0       90
# 4     55        44.6       20.4     4.0    143040                  0       90
#
#            kickoff_time  was_home  play_time_category
# ...

# %% [markdown]
# ### Normalize

# %%
from sklearn.preprocessing import MinMaxScaler

features_need_scaling = ['total_points', 'bonus', 'value', 'creativity', 'influence', 'threat', 'selected', 'transfers_balance']

scaler = MinMaxScaler()
fts[features_need_scaling] = scaler.fit_transform(fts[features_need_scaling])
fts.head(10)
# Out:
#                  name           team  GW     season  total_points  bonus  \
# 0      aaron connolly       Brighton   1  2020-2021      0.242424    0.0
# 1     aaron cresswell       West Ham   1  2020-2021      0.242424    0.0
# 2          aaron mooy       Brighton   1  2020-2021      0.212121    0.0
# 3      aaron ramsdale  Sheffield Utd   1  2020-2021      0.242424    0.0
# 4  abdoulaye doucoure        Everton   1  2020-2021      0.303030    0.0
# 5    aboubakar kamara         Fulham   1  2020-2021      0.272727    0.0
# 6        adama traore         Wolves   1  2020-2021      0.303030    0.0
# 7        adam forshaw          Leeds   1  2020-2021      0.212121    0.0
# 8        adam lallana       Brighton   1  2020-2021      0.242424    0.0
# 9        adam webster       Brighton   1  2020-2021      0.242424    0.0
#
#       value  creativity  influence    threat  selected  transfers_balance  \
# 0  0.161017    0.002203   0.007344  0.189349  0.003361           0.575866
# ...

# %%
fts['creativity'].describe()
# Out:
# count    112594.000000
# mean          0.030803
# std           0.074868
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.011747
# max           1.000000
# Name: creativity, dtype: float64

# %% [markdown]
# ### Create form

# %%
features = [col for col in features_need_scaling]

fts = fts.sort_values(['name', 'kickoff_time']).reset_index(drop=True)

def get_form(df, features):
    result = df.copy()
    weights = [0.1, 0.2, 0.3, 0.4] 

    for feature in features:
        rolling_feature = (
            df[df['minutes'] > 0]  
            .groupby('name')[feature]
            .apply(lambda x: x.shift(1)  
                   .rolling(window=4, min_periods=1)  
                   .apply(lambda y: sum(w * v for w, v in zip(weights[:len(y)], y)), raw=True))  
            .reset_index(level=0, drop=True)
        )
        result[f'form_{feature}'] = rolling_feature.combine_first(df[feature])
    
    return result


fts = get_form(fts, features)

# %%
fts.drop(columns=features, inplace=True)
fts
# Out:
#                   name      team  GW     season  minutes  \
# 0       aaron connolly  Brighton   1  2020-2021       45
# 1       aaron connolly  Brighton   2  2020-2021       89
# 2       aaron connolly  Brighton   3  2020-2021       73
# 3       aaron connolly  Brighton   4  2020-2021       65
# 4       aaron connolly  Brighton   5  2020-2021       12
# ...                ...       ...  ..        ...      ...
# 112589    zidane iqbal   Man Utd  35  2022-2023        0
# 112590    zidane iqbal   Man Utd  36  2022-2023        0
# 112591    zidane iqbal   Man Utd  37  2022-2023        0
# 112592    zidane iqbal   Man Utd  37  2022-2023        0
# 112593    zidane iqbal   Man Utd  38  2022-2023        0
#
#                 kickoff_time  was_home  play_time_category  form_total_points  \
# 0       2020-09-14T19:15:00Z      True                   0           0.242424
# 1       2020-09-20T13:00:00Z     False                   1           0.454545
# ...

# %%
fts[fts['name'] == 'marcus rashford']
# Out:
#                   name     team  GW     season  minutes          kickoff_time  \
# 72201  marcus rashford  Man Utd   2  2020-2021       90  2020-09-19T16:30:00Z
# 72202  marcus rashford  Man Utd   3  2020-2021       90  2020-09-26T11:30:00Z
# 72203  marcus rashford  Man Utd   4  2020-2021       90  2020-10-04T15:30:00Z
# 72204  marcus rashford  Man Utd   5  2020-2021       90  2020-10-17T19:00:00Z
# 72205  marcus rashford  Man Utd   6  2020-2021       90  2020-10-24T16:30:00Z
# ...                ...      ...  ..        ...      ...                   ...
# 72358  marcus rashford  Man Utd   6  2024-2025       72  2024-09-29T15:30:00Z
# 72359  marcus rashford  Man Utd   7  2024-2025       63  2024-10-06T13:00:00Z
# 72360  marcus rashford  Man Utd   8  2024-2025       90  2024-10-19T14:00:00Z
# 72361  marcus rashford  Man Utd   9  2024-2025       58  2024-10-27T14:00:00Z
# 72362  marcus rashford  Man Utd  10  2024-2025       72  2024-11-03T16:30:00Z
#
# ...

# %%
fts.drop(columns=['minutes', 'kickoff_time'], inplace=True)

# %%
# check if there is any team name in fts that is not in the value of the map
fts['team'].unique()
# Out:
# array(['Brighton', 'West Ham', 'Brentford', 'Burnley', 'Sheffield Utd',
#        'Arsenal', 'Southampton', 'Aston Villa', 'Man Utd', 'Everton',
#        'Leicester', 'Chelsea', 'Fulham', 'Norwich', 'Leeds', 'Watford',
#        'Bournemouth', 'Crystal Palace', 'Wolves', 'Luton', 'Liverpool',
#        'Man City', 'West Brom', 'Spurs', "Nott'm Forest", 'Newcastle',
#        'Ipswich'], dtype=object)

# %%
team_name_map = {
    'Arsenal' : 'ARS',
    'Aston Villa': 'AVL',
    'Bournemouth': 'BOU',
    'Brentford': 'BRE',
    'Brighton': 'BHA',
    'Burnley': 'BUR',
    'Chelsea': 'CHE',
    'Crystal Palace': 'CRY',
    'Everton': 'EVE',
    'Fulham': 'FUL',
    'Ipswich': 'IPS',
    'Leicester': 'LEI',
    'Liverpool' : 'LIV',
    'Luton': 'LUT',
    'Man City': 'MCI',
    'Man Utd': 'MUN',
    'Newcastle': 'NEW',
    'Nott\'m Forest': 'NFO',
    'Sheffield Utd': 'SHU',
    'Spurs': 'TOT',
    'West Ham': 'WHU',
    'Wolves': 'WOL',
    'Leeds': 'LEE',
    'Norwich': 'NOR',
    'Watford': 'WAT',
    'West Brom': 'WBA',
    'Cardiff': 'CAR',
    'Southampton': 'SOU'
}

# %%
set(fts['team'].unique()) - set(team_name_map.keys())
# Out:
# set()

# %%
fts.rename(columns={'GW': 'round'}, inplace=True)

# %%
fts['team'] = fts['team'].apply(lambda x: team_name_map[x])
fts.head(10)
# Out:
#              name team  round     season  was_home  play_time_category  \
# 0  aaron connolly  BHA      1  2020-2021      True                   0
# 1  aaron connolly  BHA      2  2020-2021     False                   1
# 2  aaron connolly  BHA      3  2020-2021      True                   1
# 3  aaron connolly  BHA      4  2020-2021     False                   1
# 4  aaron connolly  BHA      5  2020-2021     False                   0
# 5  aaron connolly  BHA      6  2020-2021      True                   0
# 6  aaron connolly  BHA      7  2020-2021     False                   0
# 7  aaron connolly  BHA      8  2020-2021      True                   0
# 8  aaron connolly  BHA      9  2020-2021     False                   0
# 9  aaron connolly  BHA     10  2020-2021      True                   1
#
#    form_total_points  form_bonus  form_value  form_creativity  form_influence  \
# 0           0.242424    0.000000    0.161017         0.002203        0.007344
# ...

# %% [markdown]
# ### Players Name

# %%
player_info = pd.read_csv('../../data/raw/worldfb/worldfb_players.csv')
player_info
# Out:
#           Season  Round          Team             Player Name  Is Home
# 0      2019-2020      1  Liverpool FC          Alisson Becker        1
# 1      2019-2020      1  Liverpool FC         Virgil van Dijk        1
# 2      2019-2020      1  Liverpool FC               Joe Gomez        1
# 3      2019-2020      1  Liverpool FC          Andy Robertson        1
# 4      2019-2020      1  Liverpool FC  Trent Alexander-Arnold        1
# ...          ...    ...           ...                     ...      ...
# 78593  2024-2025     11    Arsenal FC            Jakub Kiwior        0
# 78594  2024-2025     11    Arsenal FC     Oleksandr Zinchenko        0
# 78595  2024-2025     11    Arsenal FC                Jorginho        0
# 78596  2024-2025     11    Arsenal FC      Myles Lewis-Skelly        0
# 78597  2024-2025     11    Arsenal FC           Ethan Nwaneri        0
#
# [78598 rows x 5 columns]

# %%
mapping = {
    'Fulham FC': 'FUL',
    'Arsenal FC': 'ARS',
    'Crystal Palace': 'CRY',
    'Southampton FC': 'SOU',
    'Liverpool FC': 'LIV',
    'Leeds United': 'LEE',
    'West Ham United': 'WHU',
    'Newcastle United': 'NEW',
    'West Bromwich Albion': 'WBA',
    'Leicester City': 'LEI',
    'Tottenham Hotspur': 'TOT',
    'Everton FC': 'EVE',
    'Sheffield United': 'SHU',
    'Wolverhampton Wanderers': 'WOL',
    'Brighton & Hove Albion': 'BHA',
    'Chelsea FC': 'CHE',
    'Burnley FC': 'BUR',
    'Manchester United': 'MUN',
    'Manchester City': 'MCI',
    'Aston Villa': 'AVL',
    'Brentford FC': 'BRE',
    'Watford FC': 'WAT',
    'Norwich City': 'NOR',
    'AFC Bournemouth': 'BOU',
    'Nottingham Forest': 'NFO',
    'Luton Town': 'LUT',
    'Ipswich Town': 'IPS'
}

player_info['Team'] = player_info['Team'].apply(lambda x: mapping[x] if x in mapping else x)
player_info['Team'].unique()
# Out:
# array(['LIV', 'NOR', 'WHU', 'MCI', 'BOU', 'SHU', 'BUR', 'SOU', 'CRY',
#        'EVE', 'WAT', 'BHA', 'TOT', 'AVL', 'LEI', 'WOL', 'NEW', 'ARS',
#        'MUN', 'CHE', 'FUL', 'LEE', 'WBA', 'BRE', 'NFO', 'LUT', 'IPS'],
#       dtype=object)

# %%
player_info = player_info[player_info['Season'].isin(['2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025'])]

# %%
# # get the team for each player in diff
# diff = set(fts['name'].unique()) - set(player_info['Player Name'].unique())
# diff_map = fts[['name', 'team']].drop_duplicates()
# diff_map = diff_map[diff_map['name'].isin(diff)]
# diff_map

# %%
player_info['Player Name'] = player_info['Player Name'].apply(lambda x: normalize_name(x))
player_info['Player Name'].nunique()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5096\2686757649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_info['Player Name'] = player_info['Player Name'].apply(lambda x: normalize_name(x))
# 1514

# %%
fts_redundant = set(fts['name'].unique()) - set(player_info['Player Name'].unique())
fts_redundant
# Out:
# {'aaron mooy',
#  'abdul rahman baba',
#  'adedapo awokoya-mebude',
#  'admiral muskwe',
#  'adrian mazilu',
#  'adrien silva',
#  'albian ajeti',
#  'alex paulsen',
#  'alfie mawson',
#  'andre gray',
#  'angelo gabriel borges damaceno',
#  'aribim pepple',
#  'barry douglas',
#  'bastien meupiyou',
#  'ben wilmot',
#  'bendeguz bolla',
#  'braian ojeda rodriguez',
#  'brandon pierrick',
#  'brice samba',
#  'bruno borges fernandes',
#  'bruno cavaco jordao',
#  'caleb wiley',
#  'cameron carter-vickers',
#  'cameron humphreys',
#  'carlos mendes gomes',
#  'chris smalling',
#  'christian atsu',
#  'claudio bravo',
#  'corrie ndaba',
#  'darko churlinov',
#  'denis franchi',
#  'dion pereira',
#  'domingos quina',
#  'elkan baggott',
#  'enock agyei',
#  'enzo barrenechea',
#  'ethan wady',
#  'filip benkovic',
#  'florian lejeune',
#  'freddie ladapo',
#  'gabriel slonina',
#  'garang kuol',
#  'glen rea',
#  'glenn murray',
#  'gustavo nunes fernandes gomes',
#  'harry arter',
# ...

# %%
fts = fts[~fts['name'].isin(fts_redundant)]
fts['name'].nunique()
# Out:
# 1510

# %%
player_info_redundant = set(player_info['Player Name'].unique()) - set(fts['name'].unique())
# remove row where player name is in player_info_redundant
player_info = player_info[~player_info['Player Name'].isin(player_info_redundant)]
player_info
# Out:
#           Season  Round Team          Player Name  Is Home
# 14034  2020-2021      1  FUL          marek rodak        1
# 14035  2020-2021      1  FUL       michael hector        1
# 14036  2020-2021      1  FUL           denis odoi        1
# 14037  2020-2021      1  FUL             tim ream        1
# 14038  2020-2021      1  FUL            joe bryan        1
# ...          ...    ...  ...                  ...      ...
# 78593  2024-2025     11  ARS         jakub kiwior        0
# 78594  2024-2025     11  ARS  oleksandr zinchenko        0
# 78595  2024-2025     11  ARS             jorginho        0
# 78596  2024-2025     11  ARS   myles lewis-skelly        0
# 78597  2024-2025     11  ARS        ethan nwaneri        0
#
# [64560 rows x 5 columns]

# %%
player_info[player_info['Player Name'] == 'cristiano ronaldo']
# Out:
#           Season  Round Team        Player Name  Is Home
# 30043  2021-2022      4  MUN  cristiano ronaldo        1
# 30623  2021-2022      5  MUN  cristiano ronaldo        0
# 30723  2021-2022      6  MUN  cristiano ronaldo        1
# 31086  2021-2022      7  MUN  cristiano ronaldo        1
# 31581  2021-2022      8  MUN  cristiano ronaldo        0
# 32240  2021-2022      9  MUN  cristiano ronaldo        1
# 32541  2021-2022     10  MUN  cristiano ronaldo        0
# 32721  2021-2022     11  MUN  cristiano ronaldo        1
# 33300  2021-2022     12  MUN  cristiano ronaldo        0
# 33823  2021-2022     13  MUN  cristiano ronaldo        0
# 34237  2021-2022     14  MUN  cristiano ronaldo        1
# 34517  2021-2022     15  MUN  cristiano ronaldo        1
# 34897  2021-2022     16  MUN  cristiano ronaldo        0
# 35413  2021-2022     17  MUN  cristiano ronaldo        0
# 35709  2021-2022     18  MUN  cristiano ronaldo        1
# ...

# %%
player_info.to_csv('../../data/preprocessed/info/player_info.csv', index=False)

# %%
# create home_1, away_1, home_0, away_0
fts_home_1 = fts[(fts['was_home'] == True) & (fts['play_time_category'] == 1)]
fts_away_1 = fts[(fts['was_home'] == False) & (fts['play_time_category'] == 1)]
fts_home_0 = fts[(fts['was_home'] == True) & (fts['play_time_category'] == 0)]
fts_away_0 = fts[(fts['was_home'] == False) & (fts['play_time_category'] == 0)]

# %%
fts_home_0.to_csv('../../data/preprocessed/layer2/fts_home_0.csv', index=False)
fts_home_1.to_csv('../../data/preprocessed/layer2/fts_home_1.csv', index=False)
fts_away_0.to_csv('../../data/preprocessed/layer2/fts_away_0.csv', index=False)
fts_away_1.to_csv('../../data/preprocessed/layer2/fts_away_1.csv', index=False)

# %%
matches_info = pd.read_csv('../../data/raw/worldfb/worldfb_matches.csv')
matches_info.head()
# Out:
#       Match ID     Season  Round        Home Team         Away Team  \
# 0  2019-2020_1  2019-2020      1     Liverpool FC      Norwich City
# 1  2019-2020_2  2019-2020      1  West Ham United   Manchester City
# 2  2019-2020_3  2019-2020      1  AFC Bournemouth  Sheffield United
# 3  2019-2020_4  2019-2020      1       Burnley FC    Southampton FC
# 4  2019-2020_5  2019-2020      1   Crystal Palace        Everton FC
#
#           Home Coach        Away Coach
# 0       Jürgen Klopp      Daniel Farke
# 1  Manuel Pellegrini     Pep Guardiola
# 2         Eddie Howe      Chris Wilder
# 3         Sean Dyche  Ralph Hasenhüttl
# 4        Roy Hodgson       Marco Silva

# %%
matches_info['Home Team'] = matches_info['Home Team'].apply(lambda x: mapping[x] if x in mapping else x)
matches_info['Away Team'] = matches_info['Away Team'].apply(lambda x: mapping[x] if x in mapping else x)
matches_info['Home Coach'] = matches_info['Home Coach'].apply(lambda x: normalize_name(x))
matches_info['Away Coach'] = matches_info['Away Coach'].apply(lambda x: normalize_name(x))
matches_info
# Out:
#             Match ID     Season  Round Home Team Away Team  \
# 0        2019-2020_1  2019-2020      1       LIV       NOR
# 1        2019-2020_2  2019-2020      1       WHU       MCI
# 2        2019-2020_3  2019-2020      1       BOU       SHU
# 3        2019-2020_4  2019-2020      1       BUR       SOU
# 4        2019-2020_5  2019-2020      1       CRY       EVE
# ...              ...        ...    ...       ...       ...
# 2005  2024-2025_2006  2024-2025     11       LIV       AVL
# 2006  2024-2025_2007  2024-2025     11       MUN       LEI
# 2007  2024-2025_2008  2024-2025     11       NFO       NEW
# 2008  2024-2025_2009  2024-2025     11       TOT       IPS
# 2009  2024-2025_2010  2024-2025     11       CHE       ARS
#
#                Home Coach        Away Coach
# 0            jurgen klopp      daniel farke
# 1       manuel pellegrini     pep guardiola
# 2              eddie howe      chris wilder
# 3              sean dyche  ralph hasenhuttl
# ...

# %%
matches_info = matches_info[matches_info['Season'].isin(['2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025'])]
matches_info
# Out:
#             Match ID     Season  Round Home Team Away Team  \
# 380    2020-2021_381  2020-2021      1       FUL       ARS
# 381    2020-2021_382  2020-2021      1       CRY       SOU
# 382    2020-2021_383  2020-2021      1       LIV       LEE
# 383    2020-2021_384  2020-2021      1       WHU       NEW
# 384    2020-2021_385  2020-2021      1       WBA       LEI
# ...              ...        ...    ...       ...       ...
# 2005  2024-2025_2006  2024-2025     11       LIV       AVL
# 2006  2024-2025_2007  2024-2025     11       MUN       LEI
# 2007  2024-2025_2008  2024-2025     11       NFO       NEW
# 2008  2024-2025_2009  2024-2025     11       TOT       IPS
# 2009  2024-2025_2010  2024-2025     11       CHE       ARS
#
#                Home Coach        Away Coach
# 380          scott parker      mikel arteta
# 381           roy hodgson  ralph hasenhuttl
# 382          jurgen klopp    marcelo bielsa
# 383           david moyes       steve bruce
# ...

# %%
matches_info.to_csv('../../data/preprocessed/info/matches_info.csv', index=False)
